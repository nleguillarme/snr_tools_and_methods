# %%
from taxonerd import TaxoNERD

# %%
import logging
logging.basicConfig(level=logging.ERROR)

# %% [markdown]
# ### Build TaxoNERD docker image

# %%
import docker

# %%
DOCKERFILE_PATH = "../images/TaxoNERD"

client = docker.from_env()
client.images.build(path=DOCKERFILE_PATH, tag="taxonerd:latest")
# Out:
# (<Image: 'taxonerd:latest'>, <itertools._tee at 0x7f65d4a29c80>)

# %% [markdown]
# ### Run TaxoNERD and parse results

# %%
import shutil
from glob import glob

def run_taxonerd(input_dir, output_dir):
    if os.path.isdir(output_dir):
        shutil.rmtree(output_dir)
    temp_dir = output_dir+"_temp"
    shutil.copytree(input_dir, temp_dir)
    for ann in glob(os.path.join(temp_dir, "*.ann")):
        os.remove(ann)
    volume = {os.path.abspath(temp_dir): {'bind': '/home/taxonerd/input'}, os.path.abspath(output_dir): {'bind': '/home/taxonerd/output'}}
    client = docker.from_env()
    image = client.images.get("taxonerd:latest")
    response = client.containers.run(image, "taxonerd ask --focus-on speed -i /home/taxonerd/input -o /home/taxonerd/output", volumes=volume, remove=True)
    if os.path.isdir(temp_dir):
        shutil.rmtree(temp_dir)
    return response.decode("utf-8")

# %% [markdown]
# ### Eval TaxoNERD on test corpora

# %%
from eval_utils import *

# %% [markdown]
# #### Eval on LINNAEUS GSC

# %%
PATH_TO_LINNAEUS_GT = '../corpora/LINNAEUS_GSC_brat/linnaeus_clean/test'
PATH_TO_LINNAEUS_PRED = "./output/TAXONERD_MD/LINNAEUS_pred"

# %%
run_taxonerd(PATH_TO_LINNAEUS_GT, PATH_TO_LINNAEUS_PRED)
# Out:
# {'/home/leguilln/workspace/INFORMATION_EXTRACTION/snr_tools_and_methods/eval/output/TAXONERD_MD/LINNAEUS_pred_temp': {'bind': '/home/taxonerd/input'}, '/home/leguilln/workspace/INFORMATION_EXTRACTION/snr_tools_and_methods/eval/output/TAXONERD_MD/LINNAEUS_pred': {'bind': '/home/taxonerd/output'}}
# ''

# %%
get_precision_recall_f1_single_corpus(PATH_TO_LINNAEUS_PRED, PATH_TO_LINNAEUS_GT, criterion=exact)
# Out:
# $51.75$ & $26.56$ & $35.10$
#        precision    recall  f1-score
# Taxon   0.517471  0.265585  0.351016

# %%
get_precision_recall_f1_single_corpus(PATH_TO_LINNAEUS_PRED, PATH_TO_LINNAEUS_GT, criterion=approximate)
# Out:
# $56.57$ & $29.08$ & $38.42$
#        precision    recall  f1-score
# Taxon   0.565724  0.290847  0.384181

# %%
FN, FP, TP = get_FN_FP_TP_single_corpus(PATH_TO_LINNAEUS_PRED, PATH_TO_LINNAEUS_GT, criterion=approximate)
FP
# Out:
# [{'start': 4711, 'end': 4713, 'text': 'OT'},
#  {'start': 5636, 'end': 5640, 'text': 'SLPS'},
#  {'start': 6494, 'end': 6508, 'text': 'ministries)[23'},
#  {'start': 1554, 'end': 1562, 'text': 'ABSTRACT'},
#  {'start': 3432, 'end': 3444, 'text': 'tetrazolides'},
#  {'start': 3860, 'end': 3897, 'text': 'oligonucleoside methylphosphophonates'},
#  {'start': 5682, 'end': 5692, 'text': 'y-32P]-ATP'},
#  {'start': 7142,
#   'end': 7186,
#   'text': 'Protected Oligonucleoside Methylphosphonates'},
#  {'start': 10379, 'end': 10383, 'text': 'MSNT'},
#  {'start': 14194, 'end': 14200, 'text': 'buffer'},
#  {'start': 18949, 'end': 18958, 'text': 'y-32P]ATP'},
#  {'start': 19513, 'end': 19532, 'text': 'Gel Electrophoresis'},
#  {'start': 21177,
#   'end': 21221,
#   'text': 'Protected Oligonucleoside Methylphosphonates'},
#  {'start': 22083, 'end': 22088, 'text': 'DMTrO'},
#  {'start': 32586, 'end': 32596, 'text': 'Ol igomers'},
#  {'start': 32684, 'end': 32694, 'text': 'Ol igomers'},
#  {'start': 33082, 'end': 33091, 'text': 'AAAGCAAGc'},
#  {'start': 36842, 'end': 36846, 'text': 'dTpA'},
#  {'start': 38693, 'end': 38702, 'text': 'y-32p]ATP'},
#  {'start': 39131, 'end': 39161, 'text': 'partTaT fy?rlysis of dl2pApApA'},
#  {'start': 39322, 'end': 39339, 'text': 'd-3Kp-ApGRCpApApG'},
#  {'start': 40647, 'end': 40655, 'text': 'd-32pApA'},
#  {'start': 40817, 'end': 40832, 'text': 'd32pApGpCpApApG'},
#  {'start': 41308, 'end': 41324, 'text': 'd-32pApGpCpApApG'},
#  {'start': 43543, 'end': 43548, 'text': 'Dreon'},
#  {'start': 3960, 'end': 3970, 'text': 'C enzyrrme'},
#  {'start': 4831, 'end': 4840, 'text': 'A enzyrme'},
#  {'start': 6147, 'end': 6161, 'text': 'Dithiothreitol'},
#  {'start': 7300, 'end': 7304, 'text': 'DEAE'},
#  {'start': 8123, 'end': 8127, 'text': 'DEAE'},
#  {'start': 8821, 'end': 8825, 'text': 'DEAE'},
#  {'start': 10231, 'end': 10235, 'text': 'DEAE'},
#  {'start': 12018, 'end': 12022, 'text': 'DEAE'},
#  {'start': 13598, 'end': 13602, 'text': 'DEAE'},
#  {'start': 17156, 'end': 17166, 'text': 'A enzyrrme'},
#  {'start': 20221, 'end': 20229, 'text': 'oligo(dT'},
#  {'start': 20313, 'end': 20320, 'text': 'poly(dT'},
#  {'start': 20396, 'end': 20403, 'text': 'poly(dT'},
#  {'start': 24275, 'end': 24282, 'text': 'Yoshida'},
#  {'start': 24998, 'end': 25009, 'text': 'Vithayathil'},
#  {'start': 1478, 'end': 1490, 'text': 'spina bifida'},
#  {'start': 4006, 'end': 4028, 'text': 'extensor digiti minimi'},
#  {'start': 2415, 'end': 2427, 'text': 'PxxCC motifs'},
#  {'start': 4410, 'end': 4422, 'text': 'Triton X-100'},
#  {'start': 17140, 'end': 17146, 'text': 'motifs'},
#  {'start': 20483, 'end': 20487, 'text': 'DTME'},
#  {'start': 22769, 'end': 22777, 'text': 'Leu14Cys'},
#  {'start': 22782, 'end': 22790, 'text': 'Phe17Cys'},
#  {'start': 23595, 'end': 23603, 'text': 'Ala81Cys'},
#  {'start': 23609, 'end': 23617, 'text': 'Gly77Cys'},
#  {'start': 24282, 'end': 24290, 'text': 'Leu14Cys'},
#  {'start': 24292, 'end': 24300, 'text': 'Phe17Cys'},
#  {'start': 24305, 'end': 24313, 'text': 'Gly80Cys'},
#  {'start': 33332, 'end': 33340, 'text': 'Asn18Tyr'},
#  {'start': 37001, 'end': 37009, 'text': 'Ala81Leu'},
#  {'start': 37465, 'end': 37473, 'text': 'Ala81Leu'},
#  {'start': 40726, 'end': 40734, 'text': 'glycines'},
#  {'start': 41648, 'end': 41676, 'text': 'Pierce Endogen (Rockford, IL'},
#  {'start': 44405, 'end': 44409, 'text': 'DTME'},
#  {'start': 40514, 'end': 40518, 'text': 'BHNI'},
#  {'start': 175, 'end': 178, 'text': 'SLE'},
#  {'start': 1987, 'end': 2015, 'text': 'Systemic lupus erythematosus'},
#  {'start': 2225, 'end': 2230, 'text': 'lupus'},
#  {'start': 3053, 'end': 3056, 'text': 'SLE'},
#  {'start': 4850, 'end': 4878, 'text': 'Systemic lupus erythematosus'},
#  {'start': 5131, 'end': 5134, 'text': 'SLE'},
#  {'start': 8298, 'end': 8302, 'text': 'DR3-'},
#  {'start': 8304, 'end': 8308, 'text': 'DR2-'},
#  {'start': 11625, 'end': 11630, 'text': 'EHMT2'},
#  {'start': 11632, 'end': 11636, 'text': 'TNXB'},
#  {'start': 11638, 'end': 11643, 'text': 'GPSM3'},
#  {'start': 12560, 'end': 12568, 'text': 'rs605203'},
#  {'start': 12954, 'end': 12962, 'text': 'rs605203'},
#  {'start': 13524, 'end': 13527, 'text': 'SLE'},
#  {'start': 15484, 'end': 15489, 'text': 'lupus'},
#  {'start': 21779, 'end': 21785, 'text': 'SKIV2L'},
#  {'start': 27512, 'end': 27517, 'text': 'lupus'},
#  {'start': 29571, 'end': 29576, 'text': 'lupus'},
#  {'start': 31210, 'end': 31215, 'text': 'Dom3z'},
#  {'start': 31483, 'end': 31489, 'text': 'SKIV2L'},
#  {'start': 32873, 'end': 32878, 'text': 'lupus'},
#  {'start': 33171, 'end': 33186, 'text': 'lupus nephritis'},
#  {'start': 36265, 'end': 36278, 'text': 'Dynal AllSet+'},
#  {'start': 36574, 'end': 36581, 'text': 'SSPTool'},
#  {'start': 40051, 'end': 40055, 'text': 'ACLG'},
#  {'start': 2148, 'end': 2156, 'text': 'myxozoan'},
#  {'start': 2601, 'end': 2620, 'text': 'Salmonid hatcheries'},
#  {'start': 3131, 'end': 3140, 'text': 'salmonids'},
#  {'start': 3372, 'end': 3388, 'text': 'oligochaete worm'},
#  {'start': 3583, 'end': 3595, 'text': 'Actinospores'},
#  {'start': 6159, 'end': 6170, 'text': 'actinospore'},
#  {'start': 6250, 'end': 6261, 'text': 'oligochaete'},
#  {'start': 8735, 'end': 8746, 'text': 'Trout Lodge'},
#  {'start': 17000, 'end': 17007, 'text': 'PPAR-α-'},
#  {'start': 17795, 'end': 17806, 'text': 'Trout Lodge'},
#  {'start': 22970, 'end': 22981, 'text': 'Trout Lodge'},
#  {'start': 29253, 'end': 29275, 'text': 'Amino Allyl MessageAmp'},
#  {'start': 29408, 'end': 29416, 'text': 'Salmonid'},
#  {'start': 1580, 'end': 1592, 'text': 'gonadotropin'},
#  {'start': 3775, 'end': 3784, 'text': 'proestrus'},
#  {'start': 4112, 'end': 4118, 'text': 'CIIZ-V'},
#  {'start': 5813, 'end': 5835, 'text': 'Unilateral ovariectomy'},
#  {'start': 6703, 'end': 6706, 'text': 'ULO'},
#  {'start': 9417, 'end': 9420, 'text': 'ULO'},
#  {'start': 18432, 'end': 18435, 'text': 'ULO'},
#  {'start': 2069, 'end': 2082, 'text': 'GH deficiency'},
#  {'start': 2980, 'end': 2994, 'text': 'GH deficiency’'},
#  {'start': 4404, 'end': 4418, 'text': 'carcinoma14,15'},
#  {'start': 4910, 'end': 4922, 'text': 'mortality,19'},
#  {'start': 12214, 'end': 12234, 'text': 'populations.10,12,21'},
#  {'start': 20990, 'end': 21005, 'text': 'GH deficiency.3'},
#  {'start': 21654, 'end': 21663, 'text': 'Arg134Leu'},
#  {'start': 27747, 'end': 27760, 'text': 'GH deficiency'},
#  {'start': 3526, 'end': 3540, 'text': 'tumourigenesis'},
#  {'start': 13990, 'end': 14016, 'text': 'Adenomatous Polyposis Coli'},
#  {'start': 16507, 'end': 16511, 'text': 'VSWL'},
#  {'start': 16681, 'end': 16685, 'text': 'ASWC'},
#  {'start': 16813, 'end': 16816, 'text': 'SYL'},
#  {'start': 1298, 'end': 1306, 'text': 'ABSTRACT'},
#  {'start': 8471, 'end': 8490, 'text': 'Bi ohazard precauti'},
#  {'start': 22876, 'end': 22888, 'text': 'simian virus'},
#  {'start': 22996, 'end': 23006, 'text': 'conalbumin'},
#  {'start': 23013, 'end': 23020, 'text': 'fibroin'},
#  {'start': 23178, 'end': 23190, 'text': 'vitellogenin'},
#  {'start': 25901, 'end': 25921, 'text': 'Viral Carcinogenesis'},
#  {'start': 26654, 'end': 26664, 'text': 'Tolstoshev'},
#  {'start': 29572, 'end': 29580, 'text': 'Glesecke'},
#  {'start': 908, 'end': 919, 'text': 'P. Arsenyan'},
#  {'start': 936, 'end': 947, 'text': 'O. Zharkova'},
#  {'start': 1068, 'end': 1076, 'text': 'ABSTRACT'},
#  {'start': 2969, 'end': 2988, 'text': 'silylisoxazolines-2'},
#  {'start': 8101, 'end': 8110, 'text': 'Synthesis'},
#  {'start': 8125, 'end': 8152, 'text': 'G. Barbarella, L. Favaretto'},
#  {'start': 8425, 'end': 8450, 'text': 'P. Caramella, Tetrahedron'},
#  {'start': 8514, 'end': 8524, 'text': 'M. Veveris'},
#  {'start': 8526, 'end': 8543, 'text': 'V. Dirnens, Appl.'},
#  {'start': 8590, 'end': 8601, 'text': 'P. Arsenyan'},
#  {'start': 8603, 'end': 8613, 'text': 'M. Veveris'},
#  {'start': 8661, 'end': 8672, 'text': 'P. Arsenyan'},
#  {'start': 8755, 'end': 8766, 'text': 'P. Arsenyan'},
#  {'start': 7912, 'end': 7923, 'text': 'Nova Scotia'},
#  {'start': 16880, 'end': 16883, 'text': 'GVD'},
#  {'start': 17828, 'end': 17831, 'text': 'GVD'},
#  {'start': 17861, 'end': 17864, 'text': 'GVD'},
#  {'start': 21300, 'end': 21303, 'text': 'GVD'},
#  {'start': 22672, 'end': 22675, 'text': 'GVD'},
#  {'start': 23065, 'end': 23068, 'text': 'GVD'},
#  {'start': 51295, 'end': 51310, 'text': 'papilloma virus'},
#  {'start': 51799, 'end': 51814, 'text': 'medulloblastoma'},
#  {'start': 51816, 'end': 51828, 'text': 'glioblastoma'},
#  {'start': 63340, 'end': 63346, 'text': 'Xerces'},
#  {'start': 63543, 'end': 63557, 'text': 'partition.java'},
#  {'start': 65805, 'end': 65809, 'text': 'N.(6'},
#  {'start': 66340, 'end': 66346, 'text': 'p1(13a'},
#  {'start': 7658, 'end': 7673, 'text': 'corticosteroids'},
#  {'start': 10344, 'end': 10349, 'text': 'Aloes'},
#  {'start': 10434, 'end': 10440, 'text': 'pepper'},
#  {'start': 10814, 'end': 10823, 'text': 'Echinacea'},
#  {'start': 11578, 'end': 11583, 'text': 'Aloes'},
#  {'start': 17649, 'end': 17655, 'text': 'Pepper'},
#  {'start': 3535, 'end': 3544, 'text': 'Parkinson'},
#  {'start': 5582, 'end': 5599, 'text': 'nonhuman primates'},
#  {'start': 7573, 'end': 7597, 'text': 'Hg vapor (Yoshida et al.'},
#  {'start': 8902, 'end': 8919, 'text': 'NIH-07PLD formula'},
#  {'start': 14641, 'end': 14648, 'text': 'dogfish'},
#  {'start': 21999, 'end': 22016, 'text': 'nonhuman primates'},
#  {'start': 4536, 'end': 4542, 'text': 'MERLIN'},
#  {'start': 925, 'end': 944, 'text': 'Ribosome biogenesis'},
#  {'start': 5247, 'end': 5270, 'text': 'MATa Δenp1::his5+/pJB19'},
#  {'start': 6125, 'end': 6135, 'text': 'T. Schafer'},
#  {'start': 6649, 'end': 6654, 'text': 'pJB21'},
#  {'start': 6901, 'end': 6906, 'text': 'pJB24'},
#  {'start': 8248, 'end': 8263, 'text': 'PCR mutagenesis'},
#  {'start': 11387, 'end': 11410, 'text': 'GGTCTCTCTGCTGCCG GAAATG'},
#  {'start': 11415, 'end': 11439, 'text': 'AATGAGCCATTCGCAGTTTCACTG'},
#  {'start': 11471, 'end': 11494, 'text': 'TGTTTGTTACCT CTGGGCCCCG'},
#  {'start': 11551, 'end': 11575, 'text': 'GTTCGCCTAGAC GCTCTCTCTTC'},
#  {'start': 11888, 'end': 11911, 'text': 'GTCCGAAGC GCCATCTAGATGA'},
#  {'start': 17435, 'end': 17440, 'text': 'JBY51'},
#  {'start': 18924, 'end': 18929, 'text': 'JBY51'},
#  {'start': 25739, 'end': 25742, 'text': 'TEF'},
#  {'start': 194, 'end': 201, 'text': 'Diptera'},
#  {'start': 203, 'end': 214, 'text': 'Psychodidae'},
#  {'start': 1663, 'end': 1687, 'text': 'Phlebotominae sand flies'},
#  {'start': 1998, 'end': 2008, 'text': 'Leishmania'},
#  {'start': 3176, 'end': 3187, 'text': 'mutagenesis'},
#  {'start': 3521, 'end': 3531, 'text': 'Bractocera'},
#  {'start': 7303, 'end': 7308, 'text': 'Swhit'},
#  {'start': 8156, 'end': 8165, 'text': 'Nyssomyia'},
#  {'start': 8690, 'end': 8695, 'text': 'ICP16'},
#  {'start': 9779, 'end': 9784, 'text': 'ICP16'},
#  {'start': 10547, 'end': 10552, 'text': 'ICP16'},
#  {'start': 19636, 'end': 19647, 'text': 'Jacarepaguá'},
#  {'start': 19838, 'end': 19844, 'text': 'Ilhéus'},
#  {'start': 21412, 'end': 21421, 'text': 'Flexiprep'},
#  {'start': 23892, 'end': 23895, 'text': 'CJM'},
#  {'start': 3679, 'end': 3702, 'text': 'Social Cognitive Theory'},
#  {'start': 316, 'end': 321, 'text': 'Culex'},
#  {'start': 1008, 'end': 1022, 'text': 'Culex mosquito'},
#  {'start': 1314, 'end': 1319, 'text': 'Culex'},
#  {'start': 3109, 'end': 3117, 'text': 'AF165900'},
#  {'start': 6942, 'end': 6947, 'text': 'Culex'},
#  {'start': 7643, 'end': 7648, 'text': 'UGUCG'},
#  {'start': 7653, 'end': 7661, 'text': 'CUUCGGUG'},
#  {'start': 8142, 'end': 8147, 'text': 'Culex'},
#  {'start': 8359, 'end': 8373, 'text': 'Aedes mosquito'},
#  {'start': 9266, 'end': 9271, 'text': 'Aedes'},
#  {'start': 9273, 'end': 9283, 'text': 'Psorophora'},
#  {'start': 10189, 'end': 10194, 'text': 'Culex'},
#  {'start': 98, 'end': 129, 'text': 'Primitive Neuroectodermal Tumor'},
#  {'start': 4286, 'end': 4290, 'text': 'VP16'},
#  {'start': 7029, 'end': 7035, 'text': 'Pierce'},
#  {'start': 5614, 'end': 5617, 'text': 'SLE'},
#  {'start': 13223, 'end': 13238, 'text': 'corticosteroids'},
#  {'start': 21632, 'end': 21635, 'text': 'SLE'},
#  {'start': 24365, 'end': 24368, 'text': 'SLE'},
#  {'start': 1498, 'end': 1514, 'text': 'Burkholderiaceae'},
#  {'start': 8717, 'end': 8720, 'text': 'Pre'},
#  {'start': 9178, 'end': 9189, 'text': 'cobra venom'},
#  {'start': 12065, 'end': 12077, 'text': 'Burkholderia'},
#  {'start': 15238, 'end': 15249, 'text': 'cobra venom'},
#  {'start': 15656, 'end': 15667, 'text': 'cobra venom'},
#  {'start': 17691, 'end': 17695, 'text': 'LD50'},
#  {'start': 17779, 'end': 17783, 'text': 'LD50'},
#  {'start': 19212, 'end': 19223, 'text': 'cobra venom'},
#  {'start': 113, 'end': 137, 'text': 'Hippocampal Neurogenesis'},
#  {'start': 1775, 'end': 1787, 'text': 'neurogenesis'},
#  {'start': 3955, 'end': 3967, 'text': 'neurogenesis'},
#  {'start': 6727, 'end': 6730, 'text': 'Dcx'},
#  {'start': 7283, 'end': 7286, 'text': 'Dcx'},
#  {'start': 10884, 'end': 10895, 'text': 'hippocampus'},
#  {'start': 11233, 'end': 11237, 'text': 'Tbr2'},
#  {'start': 12688, 'end': 12690, 'text': 'DG'},
#  {'start': 12768, 'end': 12770, 'text': 'DG'},
#  {'start': 13161, 'end': 13173, 'text': 'neurogenesis'},
#  {'start': 14122, 'end': 14124, 'text': 'DG'},
#  {'start': 15854, 'end': 15864, 'text': 'Calretinin'},
#  {'start': 15900, 'end': 15904, 'text': 'Tbr1'},
#  {'start': 21315, 'end': 21341, 'text': 'ventral mesencephalon (VM)'},
#  {'start': 23876, 'end': 23880, 'text': 'Tbr1'},
#  {'start': 24400, 'end': 24405, 'text': 'NeuN+'},
#  {'start': 24462, 'end': 24467, 'text': 'virus'},
#  {'start': 26428, 'end': 26440, 'text': 'neurogenesis'},
#  {'start': 28179, 'end': 28181, 'text': 'DG'},
#  {'start': 29449, 'end': 29461, 'text': 'neurogenesis'},
#  {'start': 32943, 'end': 32967, 'text': 'hippocampal neurogenesis'},
#  {'start': 34906, 'end': 34919, 'text': 'ref guillemot'},
#  {'start': 36774, 'end': 36790, 'text': 'Moloney leukemia'},
#  {'start': 37023, 'end': 37045, 'text': 'pCS2+mtNeuroD1 plasmid'},
#  {'start': 38907, 'end': 38911, 'text': 'DAKO'},
#  {'start': 40388, 'end': 40406, 'text': 'Bromo-deoxyuridine'},
#  {'start': 40418, 'end': 40436, 'text': 'Cloro-deoxyuridine'},
#  {'start': 40542, 'end': 40554, 'text': 'neurogenesis'},
#  {'start': 46150, 'end': 46155, 'text': 'hTBR1'},
#  {'start': 46253, 'end': 46258, 'text': 'hTBR2'},
#  {'start': 46315, 'end': 46320, 'text': 'PROX1'},
#  {'start': 46367, 'end': 46372, 'text': 'hPDHX'},
#  {'start': 46752, 'end': 46758, 'text': 'hGLAST'},
#  {'start': 46813, 'end': 46819, 'text': 'hGLAST'},
#  {'start': 47092, 'end': 47102, 'text': 'Calretinin'},
#  {'start': 47153, 'end': 47159, 'text': 'hCALB2'}]

# %% [markdown]
# #### Eval on S800 GSC

# %%
PATH_TO_S800_GT = '../corpora/S800_GSC_brat/s800/test'
PATH_TO_S800_PRED = "./output/TAXONERD_MD/S800_pred"

# %%
run_taxonerd(PATH_TO_S800_GT, PATH_TO_S800_PRED)
# Out:
# {'/home/leguilln/workspace/INFORMATION_EXTRACTION/snr_tools_and_methods/eval/output/TAXONERD_MD/S800_pred_temp': {'bind': '/home/taxonerd/input'}, '/home/leguilln/workspace/INFORMATION_EXTRACTION/snr_tools_and_methods/eval/output/TAXONERD_MD/S800_pred': {'bind': '/home/taxonerd/output'}}
# ''

# %%
get_precision_recall_f1_single_corpus(PATH_TO_S800_PRED, PATH_TO_S800_GT, criterion=exact)
# Out:
# $45.74$ & $45.50$ & $45.62$
#        precision   recall  f1-score
# Taxon   0.457405  0.45502  0.456209

# %%
get_precision_recall_f1_single_corpus(PATH_TO_S800_PRED, PATH_TO_S800_GT, criterion=approximate)
# Out:
# $54.26$ & $54.05$ & $54.15$
#        precision   recall  f1-score
# Taxon   0.542595  0.54047   0.54153

# %%
FN, FP, TP = get_FN_FP_TP_single_corpus(PATH_TO_S800_PRED, PATH_TO_S800_GT, criterion=approximate)
FP
# Out:
# [{'start': 0, 'end': 25, 'text': 'Methanobacterium arcticum'},
#  {'start': 586, 'end': 602, 'text': 'Methanobacterium'},
#  {'start': 928, 'end': 953, 'text': 'Methanobacterium arcticum'},
#  {'start': 1003, 'end': 1016, 'text': 'VKM B-2371(T)'},
#  {'start': 760, 'end': 767, 'text': 'Paridae'},
#  {'start': 910, 'end': 921, 'text': 'Apicomplexa'},
#  {'start': 1190, 'end': 1202, 'text': 'colpodellids'},
#  {'start': 82, 'end': 100, 'text': 'Peridiniopsis spp.'},
#  {'start': 102, 'end': 113, 'text': 'Dinophyceae'},
#  {'start': 194, 'end': 212, 'text': 'Peridiniopsis spp.'},
#  {'start': 456,
#   'end': 496,
#   'text': 'Peridiniopsis penardii var. robusta var.'},
#  {'start': 517, 'end': 528, 'text': 'Dinophyceae'},
#  {'start': 618, 'end': 629, 'text': 'P. penardii'},
#  {'start': 791, 'end': 802, 'text': 'P. penardii'},
#  {'start': 807, 'end': 831, 'text': 'P. penardii var. robusta'},
#  {'start': 858, 'end': 866, 'text': 'P. kevei'},
#  {'start': 980, 'end': 991, 'text': 'P. penardii'},
#  {'start': 996, 'end': 1004, 'text': 'P. kevei'},
#  {'start': 1018, 'end': 1030, 'text': 'endosymbiont'},
#  {'start': 1154, 'end': 1169, 'text': 'dinoflagellates'},
#  {'start': 271, 'end': 275, 'text': 'alga'},
#  {'start': 402, 'end': 406, 'text': 'alga'},
#  {'start': 845, 'end': 854, 'text': 'Chlorella'},
#  {'start': 62, 'end': 66, 'text': 'PtrC'},
#  {'start': 70, 'end': 92, 'text': 'Pseudomonas aeruginosa'},
#  {'start': 175, 'end': 197, 'text': 'Pseudomonas aeruginosa'},
#  {'start': 410, 'end': 413, 'text': 'PAK'},
#  {'start': 1146, 'end': 1152, 'text': 'PA2486'},
#  {'start': 38, 'end': 50, 'text': 'pneumococcal'},
#  {'start': 301, 'end': 323, 'text': 'pneumococcal serotypes'},
#  {'start': 368, 'end': 377, 'text': 'serotypes'},
#  {'start': 690, 'end': 693, 'text': 'NVT'},
#  {'start': 1123, 'end': 1132, 'text': 'serotypes'},
#  {'start': 1283, 'end': 1292, 'text': 'serotypes'},
#  {'start': 145, 'end': 148, 'text': 'AMF'},
#  {'start': 430, 'end': 433, 'text': 'AMF'},
#  {'start': 764, 'end': 771, 'text': 'Perring'},
#  {'start': 774, 'end': 783, 'text': 'Hemiptera'},
#  {'start': 785, 'end': 796, 'text': 'Aleyrodidae'},
#  {'start': 864, 'end': 875, 'text': 'Hymenoptera'},
#  {'start': 877, 'end': 888, 'text': 'Aphelinidae'},
#  {'start': 945, 'end': 948, 'text': 'AMF'},
#  {'start': 1139, 'end': 1142, 'text': 'AMF'},
#  {'start': 1323, 'end': 1326, 'text': 'AMF'},
#  {'start': 812, 'end': 823, 'text': 'hypothermia'},
#  {'start': 1070, 'end': 1081, 'text': 'hypothermia'},
#  {'start': 0, 'end': 33, 'text': 'Cotterillia bromelicola nov. gen.'},
#  {'start': 71, 'end': 81, 'text': 'Ciliophora'},
#  {'start': 83, 'end': 93, 'text': 'Hypotricha'},
#  {'start': 117, 'end': 129, 'text': 'Bromeliaceae'},
#  {'start': 175, 'end': 208, 'text': 'Cotterillia bromelicola nov. gen.'},
#  {'start': 940, 'end': 961, 'text': 'kahliellid hypotrichs'},
#  {'start': 1080, 'end': 1094, 'text': 'Gonostomatidae'},
#  {'start': 1259, 'end': 1272, 'text': 'Trachelostyla'},
#  {'start': 1274, 'end': 1284, 'text': 'Gonostomum'},
#  {'start': 148, 'end': 159, 'text': 'rhabdovirus'},
#  {'start': 922, 'end': 930, 'text': 'Protozoa'},
#  {'start': 47, 'end': 60, 'text': 'Rhizobium sp.'},
#  {'start': 68, 'end': 73, 'text': 'LPU83'},
#  {'start': 410, 'end': 419, 'text': 'rhizobium'},
#  {'start': 662, 'end': 675, 'text': 'Rhizobium sp.'},
#  {'start': 683, 'end': 688, 'text': 'LPU83'},
#  {'start': 1074, 'end': 1099, 'text': 'Rhizobium mongolense USDA'},
#  {'start': 1314, 'end': 1327, 'text': 'Rhizobium sp.'},
#  {'start': 1335, 'end': 1340, 'text': 'LPU83'},
#  {'start': 54, 'end': 75, 'text': 'Australian cuttlefish'},
#  {'start': 716, 'end': 737, 'text': 'Australian cuttlefish'},
#  {'start': 313, 'end': 338, 'text': 'CpG oligodeoxynucleotides'},
#  {'start': 120, 'end': 133, 'text': 'Arboreal ants'},
#  {'start': 1228, 'end': 1232, 'text': 'ORFV'},
#  {'start': 1249, 'end': 1254, 'text': 'sheep'},
#  {'start': 1300, 'end': 1305, 'text': 'virus'},
#  {'start': 102, 'end': 110, 'text': 'Selenium'},
#  {'start': 132, 'end': 145, 'text': 'dermatophytes'},
#  {'start': 1414, 'end': 1426, 'text': 'dermatophyte'},
#  {'start': 79, 'end': 91, 'text': 'Onychiuridae'},
#  {'start': 93, 'end': 103, 'text': 'Collembola'},
#  {'start': 166, 'end': 178, 'text': 'Onychiuridae'},
#  {'start': 180, 'end': 190, 'text': 'Collembola'},
#  {'start': 29, 'end': 57, 'text': 'human immunodeficiency virus'},
#  {'start': 110, 'end': 138, 'text': 'Human immunodeficiency virus'},
#  {'start': 892, 'end': 906, 'text': 'Chlamydia spp.'},
#  {'start': 0, 'end': 9, 'text': 'Norovirus'},
#  {'start': 45, 'end': 56, 'text': 'Noroviruses'},
#  {'start': 968, 'end': 978, 'text': 'GII.4 VLPs'},
#  {'start': 1183, 'end': 1190, 'text': 'capsids'},
#  {'start': 1531, 'end': 1548, 'text': 'GII.4 noroviruses'},
#  {'start': 1647, 'end': 1650, 'text': 'HIV'},
#  {'start': 1675, 'end': 1684, 'text': 'norovirus'},
#  {'start': 18, 'end': 34, 'text': 'Virus Counter(R)'},
#  {'start': 114, 'end': 119, 'text': 'virus'},
#  {'start': 138, 'end': 143, 'text': 'Virus'},
#  {'start': 811, 'end': 816, 'text': 'Virus'},
#  {'start': 998, 'end': 1003, 'text': 'Virus'},
#  {'start': 55, 'end': 60, 'text': 'virus'},
#  {'start': 388, 'end': 396, 'text': 'Pulldown'},
#  {'start': 1289, 'end': 1294, 'text': 'virus'},
#  {'start': 909, 'end': 914, 'text': 'virus'},
#  {'start': 960, 'end': 969, 'text': 'PB2-E158G'},
#  {'start': 1063, 'end': 1068, 'text': 'virus'},
#  {'start': 1188, 'end': 1196, 'text': 'PB2-E158'},
#  {'start': 1656, 'end': 1665, 'text': 'PB2-E158G'},
#  {'start': 139, 'end': 153, 'text': 'Pezizomycotina'},
#  {'start': 396, 'end': 403, 'text': 'E. coli'},
#  {'start': 1325, 'end': 1332, 'text': 'E. coli'},
#  {'start': 2011, 'end': 2020, 'text': 'Geobacter'},
#  {'start': 63, 'end': 67, 'text': 'PBAN'},
#  {'start': 198, 'end': 207, 'text': 'pyrokinin'},
#  {'start': 256, 'end': 260, 'text': 'PBAN'},
#  {'start': 386, 'end': 395, 'text': 'pyrokinin'},
#  {'start': 441, 'end': 445, 'text': 'PBAN'},
#  {'start': 627, 'end': 636, 'text': 'pyrokinin'},
#  {'start': 637, 'end': 641, 'text': 'PBAN'},
#  {'start': 361, 'end': 374, 'text': 'H1N1pdm virus'},
#  {'start': 536, 'end': 549, 'text': 'H1N1pdm virus'},
#  {'start': 690, 'end': 699, 'text': 'H1pdm, H1'},
#  {'start': 955, 'end': 968, 'text': 'H1pdm rRT-PCR'},
#  {'start': 1009, 'end': 1018, 'text': 'A/H1N1pdm'},
#  {'start': 1097, 'end': 1107, 'text': 'mutation(s'},
#  {'start': 1542, 'end': 1551, 'text': 'H1pdm, H1'},
#  {'start': 364, 'end': 369, 'text': 'Mig1s'},
#  {'start': 96, 'end': 123, 'text': 'Japanese encephalitis virus'},
#  {'start': 266, 'end': 281, 'text': 'West Nile virus'},
#  {'start': 320, 'end': 323, 'text': 'WNV'},
#  {'start': 134, 'end': 139, 'text': 'Acari'},
#  {'start': 141, 'end': 149, 'text': 'Ixodidae'},
#  {'start': 1378, 'end': 1388, 'text': 'orcokinins'},
#  {'start': 1390, 'end': 1407, 'text': 'preprosulphakinin'},
#  {'start': 0, 'end': 15, 'text': 'Tortricid moths'},
#  {'start': 279, 'end': 290, 'text': 'Leguminosae'},
#  {'start': 292, 'end': 308, 'text': 'Caesalpinioideae'},
#  {'start': 406, 'end': 417, 'text': 'Tortricidae'},
#  {'start': 419, 'end': 430, 'text': 'Lepidoptera'},
#  {'start': 494, 'end': 520, 'text': 'Amorbia concavana (Zeller)'},
#  {'start': 522, 'end': 549, 'text': 'Platynota rostrana (Walker)'},
#  {'start': 551, 'end': 581, 'text': 'Platynota helianthes (Meyrick)'},
#  {'start': 631, 'end': 644, 'text': 'Sparganothini'},
#  {'start': 647, 'end': 673, 'text': 'Rudenia leguminana (Busck)'},
#  {'start': 675, 'end': 687, 'text': 'Cochylis sp.'},
#  {'start': 707, 'end': 716, 'text': 'Cochylini'},
#  {'start': 719, 'end': 757, 'text': 'Ofatulena duodecemstriata (Walsingham)'},
#  {'start': 759, 'end': 779, 'text': 'O. luminosa Heinrich'},
#  {'start': 800, 'end': 813, 'text': 'Olethreutinae'},
#  {'start': 815, 'end': 827, 'text': 'Grapholitini'},
#  {'start': 834, 'end': 859, 'text': 'Crocidosema lantana Busck'},
#  {'start': 876, 'end': 885, 'text': 'Eucosmini'},
#  {'start': 945, 'end': 963, 'text': 'O. duodecemstriata'},
#  {'start': 968, 'end': 981, 'text': 'R. leguminana'},
#  {'start': 1065, 'end': 1076, 'text': 'O. luminosa'},
#  {'start': 1098, 'end': 1111, 'text': 'Sparganothini'},
#  {'start': 1150, 'end': 1159, 'text': 'Cochylini'},
#  {'start': 1209, 'end': 1220, 'text': 'Leguminosae'},
#  {'start': 1222, 'end': 1240, 'text': 'Ofatulena luminosa'},
#  {'start': 1300, 'end': 1318, 'text': 'Rudenia leguminana'},
#  {'start': 1437, 'end': 1450, 'text': 'R. leguminana'},
#  {'start': 974, 'end': 983, 'text': 'Wolbachia'},
#  {'start': 985, 'end': 992, 'text': 'Delftia'},
#  {'start': 1003, 'end': 1014, 'text': 'Pseudomonas'},
#  {'start': 1017, 'end': 1031, 'text': 'Pectobacterium'},
#  {'start': 1033, 'end': 1042, 'text': 'Moraxella'},
#  {'start': 1044, 'end': 1052, 'text': 'Serratia'},
#  {'start': 1054, 'end': 1062, 'text': 'Bacillus'},
#  {'start': 1526, 'end': 1542, 'text': 'non-extremophile'},
#  {'start': 358, 'end': 390, 'text': 'Gross Chromosomal Rearrangements'},
#  {'start': 539, 'end': 543, 'text': 'PIKK'},
#  {'start': 16, 'end': 36, 'text': 'Fusarium graminearum'},
#  {'start': 243, 'end': 263, 'text': 'Fusarium graminearum'},
#  {'start': 477, 'end': 480, 'text': 'NIV'},
#  {'start': 736, 'end': 756, 'text': 'Fusarium head blight'},
#  {'start': 0, 'end': 23, 'text': 'Nocardioides caricicola'},
#  {'start': 556, 'end': 568, 'text': 'Nocardioides'},
#  {'start': 583, 'end': 598, 'text': 'Nocardioidaceae'},
#  {'start': 925, 'end': 933, 'text': 'MK-8(H(4'},
#  {'start': 1330, 'end': 1342, 'text': 'Nocardioides'},
#  {'start': 1363, 'end': 1386, 'text': 'Nocardioides caricicola'},
#  {'start': 1440, 'end': 1453, 'text': 'KACC 13778(T)'},
#  {'start': 741, 'end': 765, 'text': 'Tracheliastes polycolpus'},
#  {'start': 938, 'end': 951, 'text': 'T. polycolpus'},
#  {'start': 196, 'end': 210, 'text': 'B. burgdorferi'},
#  {'start': 85, 'end': 94, 'text': 'Wolbachia'},
#  {'start': 99, 'end': 108, 'text': 'Cardinium'},
#  {'start': 126, 'end': 135, 'text': 'Wolbachia'},
#  {'start': 140, 'end': 149, 'text': 'Cardinium'},
#  {'start': 399, 'end': 408, 'text': 'Cardinium'},
#  {'start': 470, 'end': 479, 'text': 'Wolbachia'},
#  {'start': 573, 'end': 582, 'text': 'Cardinium'},
#  {'start': 805, 'end': 814, 'text': 'Wolbachia'},
#  {'start': 819, 'end': 828, 'text': 'Cardinium'},
#  {'start': 0, 'end': 16, 'text': 'Alphacoronavirus'},
#  {'start': 31, 'end': 52, 'text': 'gastroenteritis virus'},
#  {'start': 415, 'end': 430, 'text': 'betacoronavirus'},
#  {'start': 681, 'end': 685, 'text': 'DCR2'},
#  {'start': 772, 'end': 776, 'text': 'Dcr2'},
#  {'start': 1112, 'end': 1123, 'text': 'DSM 18570(T'},
#  {'start': 1413, 'end': 1422, 'text': 'Thiomonas'},
#  {'start': 24, 'end': 35, 'text': 'Triplumaria'},
#  {'start': 45, 'end': 55, 'text': 'Ciliophora'},
#  {'start': 57, 'end': 74, 'text': 'Entodiniomorphida'},
#  {'start': 246, 'end': 263, 'text': 'Entodiniomorphida'},
#  {'start': 284, 'end': 295, 'text': 'Triplumaria'},
#  {'start': 318, 'end': 333, 'text': 'Cycloposthiidae'},
#  {'start': 396, 'end': 404, 'text': 'T. antis'},
#  {'start': 409, 'end': 420, 'text': 'T. dvoinosi'},
#  {'start': 460, 'end': 469, 'text': 'T. sukuna'},
#  {'start': 478, 'end': 485, 'text': 'T. zuze'},
#  {'start': 494, 'end': 502, 'text': 'T. solea'},
#  {'start': 511, 'end': 520, 'text': 'T. suwako'},
#  {'start': 529, 'end': 539, 'text': 'T. fulgora'},
#  {'start': 552, 'end': 565, 'text': 'T. harpagonis'},
#  {'start': 590, 'end': 599, 'text': 'T. sukuna'},
#  {'start': 601, 'end': 608, 'text': 'T. zuze'},
#  {'start': 610, 'end': 618, 'text': 'T. solea'},
#  {'start': 624, 'end': 633, 'text': 'T. suwako'},
#  {'start': 738, 'end': 747, 'text': 'T. suwako'},
#  {'start': 842, 'end': 851, 'text': 'T. sukuna'},
#  {'start': 853, 'end': 860, 'text': 'T. zuze'},
#  {'start': 866, 'end': 874, 'text': 'T. solea'},
#  {'start': 899, 'end': 913, 'text': 'T. grypoclunis'},
#  {'start': 943, 'end': 951, 'text': 'T. antis'},
#  {'start': 953, 'end': 964, 'text': 'T. dvoinosi'},
#  {'start': 966, 'end': 976, 'text': 'T. fulgora'},
#  {'start': 982, 'end': 995, 'text': 'T. harpagonis'},
#  {'start': 1111, 'end': 1127, 'text': 'Ophryoscolecidae'},
#  {'start': 1160, 'end': 1171, 'text': 'T. dvoinosi'},
#  {'start': 1176, 'end': 1186, 'text': 'T. fulgora'},
#  {'start': 1222, 'end': 1237, 'text': 'ophryoscolecids'},
#  {'start': 1257, 'end': 1284, 'text': 'Pseudoentodinium elephantis'},
#  {'start': 1197, 'end': 1211, 'text': 'enterobacteria'},
#  {'start': 112, 'end': 123, 'text': 'Aspergillus'},
#  {'start': 135, 'end': 146, 'text': 'Aspergillus'},
#  {'start': 1231, 'end': 1247, 'text': 'Escherichia coli'},
#  {'start': 865, 'end': 876, 'text': 'gypsy moths'},
#  {'start': 881, 'end': 896, 'text': 'native thrushes'},
#  {'start': 181, 'end': 203, 'text': 'Raphid pennate diatoms'},
#  {'start': 776, 'end': 798, 'text': 'raphid pennate diatoms'},
#  {'start': 147, 'end': 157, 'text': 'Euglyphida'},
#  {'start': 631, 'end': 639, 'text': 'Cercozoa'},
#  {'start': 641, 'end': 649, 'text': 'Rhizaria'},
#  {'start': 1199, 'end': 1212, 'text': 'Cyphoderiidae'},
#  {'start': 1328, 'end': 1341, 'text': 'Cyphoderiidae'},
#  {'start': 60, 'end': 69, 'text': 'Astomatia'},
#  {'start': 71, 'end': 81, 'text': 'Ciliophora'},
#  {'start': 122, 'end': 147, 'text': 'West African oligochaetes'},
#  {'start': 149, 'end': 165, 'text': 'Glossoscolecidae'},
#  {'start': 167, 'end': 181, 'text': 'Megascolecidae'},
#  {'start': 223, 'end': 239, 'text': 'Paraclausilocola'},
#  {'start': 603, 'end': 630, 'text': 'Paraclausilocola constricta'},
#  {'start': 652, 'end': 677, 'text': 'Paraclausilocola elongata'},
#  {'start': 725, 'end': 738, 'text': 'clausilocolid'},
#  {'start': 745, 'end': 761, 'text': 'Paraclausilocola'},
#  {'start': 1204, 'end': 1213, 'text': 'Astomatia'},
#  {'start': 663, 'end': 675, 'text': 'tuberculosis'},
#  {'start': 1099, 'end': 1112, 'text': 'leptospirosis'},
#  {'start': 1286, 'end': 1294, 'text': 'cue-prey'},
#  {'start': 1428, 'end': 1432, 'text': 'prey'},
#  {'start': 91, 'end': 101, 'text': 'Neurospora'},
#  {'start': 367, 'end': 390, 'text': 'Neurospora mitochondria'},
#  {'start': 714, 'end': 724, 'text': 'Neurospora'},
#  {'start': 1211, 'end': 1234, 'text': 'Neurospora mitochondria'},
#  {'start': 1400, 'end': 1424, 'text': 'Neurospora mitochondrial'},
#  {'start': 0, 'end': 7, 'text': 'Hypoxia'},
#  {'start': 306, 'end': 316, 'text': 'Salmonella'},
#  {'start': 322, 'end': 332, 'text': 'Salmonella'},
#  {'start': 897, 'end': 901, 'text': 'PhoP'},
#  {'start': 1071, 'end': 1081, 'text': 'Holopedium'},
#  {'start': 1097, 'end': 1109, 'text': 'Bythotrephes'},
#  {'start': 1146, 'end': 1156, 'text': 'Holopedium'},
#  {'start': 1275, 'end': 1285, 'text': 'Holopedium'},
#  {'start': 662, 'end': 667, 'text': 'moose'},
#  {'start': 0, 'end': 21, 'text': 'Streptococcus ursoris'},
#  {'start': 232, 'end': 245, 'text': 'streptococcal'},
#  {'start': 397, 'end': 410, 'text': 'Streptococcus'},
#  {'start': 765, 'end': 786, 'text': 'mitis salivarius agar'},
#  {'start': 969, 'end': 982, 'text': 'Streptococcus'},
#  {'start': 986, 'end': 1007, 'text': 'Streptococcus ursoris'},
#  {'start': 35, 'end': 47, 'text': 'Osteoporosis'},
#  {'start': 1253, 'end': 1264, 'text': 'Arcellinida'},
#  {'start': 1269, 'end': 1279, 'text': 'Euglyphida'},
#  {'start': 1350, 'end': 1361, 'text': 'cryptomonad'},
#  {'start': 732, 'end': 736, 'text': 'MAbs'},
#  {'start': 1437, 'end': 1441, 'text': 'MAbs'},
#  {'start': 52, 'end': 55, 'text': 'HIV'},
#  {'start': 135, 'end': 138, 'text': 'HIV'},
#  {'start': 565, 'end': 568, 'text': 'HIV'},
#  {'start': 1225, 'end': 1228, 'text': 'CAF'},
#  {'start': 125, 'end': 134, 'text': 'Wolbachia'},
#  {'start': 370, 'end': 379, 'text': 'Wolbachia'},
#  {'start': 691, 'end': 700, 'text': 'Wolbachia'},
#  {'start': 969, 'end': 979, 'text': 'Solenopsis'},
#  {'start': 1025, 'end': 1034, 'text': 'Wolbachia'},
#  {'start': 899, 'end': 908, 'text': 'Hemiptera'},
#  {'start': 428, 'end': 434, 'text': 'AeOSBP'},
#  {'start': 436, 'end': 442, 'text': 'AeORP1'},
#  {'start': 321, 'end': 324, 'text': 'HIV'},
#  {'start': 727, 'end': 735, 'text': 'Yearling'},
#  {'start': 0, 'end': 24, 'text': 'Rhizomastix biflagellata'},
#  {'start': 126, 'end': 137, 'text': 'Rhizomastix'},
#  {'start': 462, 'end': 473, 'text': 'Rhizomastix'},
#  {'start': 519, 'end': 530, 'text': 'horned frog'},
#  {'start': 558, 'end': 569, 'text': 'Rhizomastix'},
#  {'start': 645, 'end': 669, 'text': 'Rhizomastix biflagellata'},
#  {'start': 706, 'end': 717, 'text': 'Rhizomastix'},
#  {'start': 721, 'end': 732, 'text': 'Archamoebae'},
#  {'start': 1068, 'end': 1080, 'text': 'Chaenogobius'},
#  {'start': 1601, 'end': 1608, 'text': 'gobiids'},
#  {'start': 136, 'end': 147, 'text': 'planthopper'},
#  {'start': 268, 'end': 283, 'text': 'Dalbulus maidis'},
#  {'start': 307, 'end': 316, 'text': 'Hemiptera'},
#  {'start': 318, 'end': 330, 'text': 'Cicadellidae'},
#  {'start': 340, 'end': 351, 'text': 'planthopper'},
#  {'start': 353, 'end': 380, 'text': 'Delphacodes kuscheli Fennah'},
#  {'start': 382, 'end': 391, 'text': 'Hemiptera'},
#  {'start': 393, 'end': 404, 'text': 'Delphacidae'},
#  {'start': 494, 'end': 504, 'text': 'mollicutes'},
#  {'start': 637, 'end': 647, 'text': 'Ascomycota'},
#  {'start': 881, 'end': 887, 'text': 'lipids'},
#  {'start': 1133, 'end': 1148, 'text': 'Cordycipitaceae'},
#  {'start': 1661, 'end': 1671, 'text': 'Bacillaeae'},
#  {'start': 189, 'end': 201, 'text': 'camptocormia'},
#  {'start': 648, 'end': 656, 'text': 'Colpodea'},
#  {'start': 825, 'end': 841, 'text': 'Cyrtolophosidida'},
#  {'start': 937, 'end': 947, 'text': 'Sorogenida'},
#  {'start': 1129, 'end': 1137, 'text': 'Colpodea'},
#  {'start': 912, 'end': 933, 'text': 'predaceous arthropods'},
#  {'start': 565, 'end': 581, 'text': 'brushtail possum'},
#  {'start': 30, 'end': 41, 'text': 'parasitoids'},
#  {'start': 56, 'end': 68, 'text': 'pteromalidae'},
#  {'start': 597, 'end': 608, 'text': 'parasitoids'},
#  {'start': 862, 'end': 876, 'text': 'Spalangia spp.'},
#  {'start': 1266, 'end': 1280, 'text': 'Spalangia spp.'},
#  {'start': 1454, 'end': 1471, 'text': 'Muscidifurax spp.'},
#  {'start': 388, 'end': 393, 'text': 'pilus'},
#  {'start': 1098, 'end': 1103, 'text': 'pilus'},
#  {'start': 472, 'end': 486, 'text': 'B. rhizoxinica'},
#  {'start': 163, 'end': 172, 'text': 'serotypes'},
#  {'start': 361, 'end': 370, 'text': 'serotypes'},
#  {'start': 419, 'end': 439, 'text': 'Fusarium head blight'},
#  {'start': 43, 'end': 55, 'text': 'chrysomonads'},
#  {'start': 56, 'end': 70, 'text': 'Ochromonas sp.'},
#  {'start': 299, 'end': 313, 'text': 'Ochromonas sp.'},
#  {'start': 999, 'end': 1013, 'text': 'Ochromonas sp.'},
#  {'start': 559, 'end': 564, 'text': 'virus'},
#  {'start': 661, 'end': 673, 'text': 'picornavirus'},
#  {'start': 275, 'end': 281, 'text': 'bmGSTO'},
#  {'start': 830, 'end': 836, 'text': 'bmGSTO'},
#  {'start': 122, 'end': 141, 'text': 'Lipopolysaccharides'},
#  {'start': 766, 'end': 779, 'text': 'Bacteroidetes'},
#  {'start': 1380, 'end': 1392, 'text': 'KACC 14040(T'},
#  {'start': 1395, 'end': 1409, 'text': 'NBRC 106324(T)'}]

# %% [markdown]
# #### Eval on COPIOUS GSC

# %%
PATH_TO_COPIOUS_GT = '../corpora/COPIOUS_GSC_brat/copious_clean/test'
PATH_TO_COPIOUS_PRED = "./output/TAXONERD_MD/COPIOUS_pred"

# %%
run_taxonerd(PATH_TO_COPIOUS_GT, PATH_TO_COPIOUS_PRED)

# %%
get_precision_recall_f1_single_corpus(PATH_TO_COPIOUS_PRED, PATH_TO_COPIOUS_GT, criterion=exact)
# Out:
# $75.77$ & $67.45$ & $71.37$
#        precision   recall  f1-score
# Taxon   0.757709  0.67451  0.713693

# %%
get_precision_recall_f1_single_corpus(PATH_TO_COPIOUS_PRED, PATH_TO_COPIOUS_GT, criterion=approximate)
# Out:
# $82.49$ & $74.09$ & $78.06$
#        precision    recall  f1-score
# Taxon    0.82489  0.740851  0.780615

# %%
FN, FP, TP = get_FN_FP_TP_single_corpus(PATH_TO_COPIOUS_PRED, PATH_TO_COPIOUS_GT, criterion=approximate)
FP
# Out:
# [{'start': 0, 'end': 3, 'text': 'MAI'},
#  {'start': 346, 'end': 366, 'text': 'S. parvlfolius Bastw'},
#  {'start': 393, 'end': 411, 'text': 'S. tetonensis Nels'},
#  {'start': 562, 'end': 580, 'text': "Stotiiach ?'ecords"},
#  {'start': 2315, 'end': 2340, 'text': 'Taxodinm ascendens Brongn'},
#  {'start': 184, 'end': 188, 'text': 'deer'},
#  {'start': 1544, 'end': 1548, 'text': 'deer'},
#  {'start': 4, 'end': 12, 'text': 'BARBICAN'},
#  {'start': 284, 'end': 305, 'text': 'Black-throated Barbet'},
#  {'start': 1533, 'end': 1548, 'text': 'Bucco rufifrons'},
#  {'start': 382, 'end': 397, 'text': 'Saipan Okinawan'},
#  {'start': 2419, 'end': 2434, 'text': 'Salpan Okinawan'},
#  {'start': 42, 'end': 70, 'text': 'Archamia bleekeri (Glinther)'},
#  {'start': 1409, 'end': 1424, 'text': 'Ambassis lung-i'},
#  {'start': 1679, 'end': 1691, 'text': 'fruit thrush'},
#  {'start': 1758, 'end': 1777, 'text': 'Cerithium macrotoma'},
#  {'start': 1912, 'end': 1929, 'text': 'Oolina pupiformis'},
#  {'start': 2286, 'end': 2300, 'text': 'Colina pygmsea'},
#  {'start': 917, 'end': 923, 'text': 'sawale'},
#  {'start': 475, 'end': 487, 'text': 'Endodontidae'},
#  {'start': 558, 'end': 570, 'text': 'Endodontidae'},
#  {'start': 259, 'end': 274, 'text': 'valvis lignosis'},
#  {'start': 740, 'end': 768, 'text': 'Hydnocarpus beccariana Sleum'},
#  {'start': 2211, 'end': 2239, 'text': 'Hydnocarpus borneensis Sleum'},
#  {'start': 3194, 'end': 3198, 'text': 'Vh-2'},
#  {'start': 4279, 'end': 4316, 'text': 'Hydnocarpus filipes Symington & Sleum'},
#  {'start': 15, 'end': 25, 'text': 'MAI TAKIEN'},
#  {'start': 236, 'end': 246, 'text': 'Fragmentos'},
#  {'start': 360, 'end': 370, 'text': 'Doleschall'},
#  {'start': 1165, 'end': 1188, 'text': 'Cavallium urens, Schott'},
#  {'start': 5, 'end': 21, 'text': 'DIPTEROCARPACEAE'},
#  {'start': 1525, 'end': 1538, 'text': 'S. parvifolia'},
#  {'start': 1643, 'end': 1658, 'text': 'S. plagata FOXW'},
#  {'start': 1718, 'end': 1737, 'text': 'S. agsaboensis W.L.'},
#  {'start': 4017, 'end': 4026, 'text': 'P. Musala'},
#  {'start': 4806, 'end': 4813, 'text': 'P. ROJO'},
#  {'start': 5404, 'end': 5412, 'text': 'S. ovata'},
#  {'start': 618, 'end': 630, 'text': 'Alibiba rafi'},
#  {'start': 805, 'end': 810, 'text': 'Taura'},
#  {'start': 960, 'end': 968, 'text': 'Naraguta'},
#  {'start': 75, 'end': 82, 'text': 'gibbons'},
#  {'start': 799, 'end': 806, 'text': 'Malayan'},
#  {'start': 1486, 'end': 1497, 'text': 'lumbricoids'},
#  {'start': 1234, 'end': 1251, 'text': 'Koo7dersiodendron'},
#  {'start': 1391, 'end': 1418, 'text': 'Albizzia julibrissin Durazz'},
#  {'start': 1381, 'end': 1391, 'text': 'Louisiades'},
#  {'start': 1464, 'end': 1496, 'text': 'Plectropoma leopardus Richardson'},
#  {'start': 42, 'end': 68, 'text': 'THYSANOLAENA MAXIMA (Roxb)'},
#  {'start': 2106, 'end': 2127, 'text': 'Panicum pruriens Trin'},
#  {'start': 737, 'end': 748, 'text': 'Platymantis'},
#  {'start': 1059, 'end': 1070, 'text': 'Platymantis'},
#  {'start': 1748, 'end': 1757, 'text': 'guentheri'},
#  {'start': 14, 'end': 38, 'text': 'USSA CHRYSOTRICHOS Heude'},
#  {'start': 46, 'end': 70, 'text': 'Ussa chrysotrichos Heude'},
#  {'start': 191, 'end': 210, 'text': 'Ussa cinereus Heude'},
#  {'start': 315, 'end': 335, 'text': 'Ussa corteanus Heude'},
#  {'start': 447, 'end': 470, 'text': 'Ussa crassicornis Heude'},
#  {'start': 572, 'end': 597, 'text': 'Ussa dailliardianus Heude'},
#  {'start': 688, 'end': 697, 'text': 'Melanaxis'},
#  {'start': 722, 'end': 731, 'text': 'Melanaxis'},
#  {'start': 860, 'end': 880, 'text': 'Ussa elorzanus Heude'},
#  {'start': 996, 'end': 1017, 'text': 'Ussa francianus Heude'},
#  {'start': 1124, 'end': 1144, 'text': 'Ussa garcianus Heude'},
#  {'start': 1255, 'end': 1276, 'text': 'Ussa gonzalinus Heude'},
#  {'start': 1398, 'end': 1420, 'text': 'Ussa gorrichanus Heude'},
#  {'start': 622, 'end': 634, 'text': 'Cycas medica'},
#  {'start': 943, 'end': 958, 'text': 'S. LAUD, Bombay'},
#  {'start': 650, 'end': 655, 'text': 'liave'},
#  {'start': 3518, 'end': 3523, 'text': 'lauan'},
#  {'start': 3970, 'end': 3981, 'text': 'A. Ventrals'},
#  {'start': 4043, 'end': 4054, 'text': 'B. Ventrals'},
#  {'start': 1555, 'end': 1563, 'text': 'Wapenaar'},
#  {'start': 2602, 'end': 2616, 'text': 'striped marlin'},
#  {'start': 3107, 'end': 3121, 'text': 'striped marlin'},
#  {'start': 2626, 'end': 2647, 'text': 'Hopea miceantha, Hook'},
#  {'start': 1704, 'end': 1714, 'text': 'overwinter'},
#  {'start': 289, 'end': 305, 'text': 'Philippine birds'},
#  {'start': 1400, 'end': 1408, 'text': 'PSITTACI'},
#  {'start': 849, 'end': 854, 'text': 'Tagal'},
#  {'start': 830, 'end': 836, 'text': 'mullet'},
#  {'start': 1464, 'end': 1470, 'text': 'palyok'},
#  {'start': 2486, 'end': 2492, 'text': 'tliiee'},
#  {'start': 175, 'end': 185, 'text': 'Pelmadulla'},
#  {'start': 417, 'end': 446, 'text': 'Rhinolophus virgo K. Anderson'},
#  {'start': 1174, 'end': 1196, 'text': 'Murina cyclotis Dobson'},
#  {'start': 1150, 'end': 1162, 'text': 'Hipposideros'},
#  {'start': 1491, 'end': 1521, 'text': 'Viverricula malacensis Cagayan'},
#  {'start': 1599, 'end': 1609, 'text': 'Petaurista'},
#  {'start': 1620, 'end': 1639, 'text': 'Funambulus vittatus'},
#  {'start': 1641, 'end': 1648, 'text': 'Sciurus'},
#  {'start': 1703, 'end': 1724, 'text': 'Semnopithecus albipes'},
#  {'start': 1762, 'end': 1770, 'text': 'Pithecus'},
#  {'start': 1799, 'end': 1807, 'text': 'Pithecus'},
#  {'start': 49, 'end': 76, 'text': 'Kerivoula whiteheadi Thomas'},
#  {'start': 219, 'end': 236, 'text': 'Chaerephon Dobson'},
#  {'start': 689, 'end': 719, 'text': 'Vespertilio plicatus Buchannan'},
#  {'start': 753, 'end': 781, 'text': 'Chaerephon plicatus Andersen'},
#  {'start': 1479, 'end': 1486, 'text': 'Mustela'},
#  {'start': 1488, 'end': 1514, 'text': 'Martes) henricii Westerman'},
#  {'start': 42, 'end': 49, 'text': 'VELIGER'},
#  {'start': 156, 'end': 165, 'text': 'H. MCLEAN'},
#  {'start': 312, 'end': 320, 'text': 'turbinid'},
#  {'start': 747, 'end': 755, 'text': 'turbinid'},
#  {'start': 1146, 'end': 1159, 'text': 'Liotina peron'},
#  {'start': 3067, 'end': 3077, 'text': 'Turbinidae'},
#  {'start': 3160, 'end': 3182, 'text': 'Liotia armata A. Adams'},
#  {'start': 12, 'end': 19, 'text': 'VELIGER'},
#  {'start': 73, 'end': 81, 'text': 'Mollusca'},
#  {'start': 83, 'end': 93, 'text': 'Gastropoda'},
#  {'start': 467, 'end': 474, 'text': 'Cypraea'},
#  {'start': 834, 'end': 839, 'text': 'litue'},
#  {'start': 26, 'end': 33, 'text': 'Monotes'},
#  {'start': 514, 'end': 521, 'text': 'Lopollo'},
#  {'start': 264, 'end': 284, 'text': 'Ipomaea biloba Forsk'},
#  {'start': 2811, 'end': 2831, 'text': 'Tetrameles nudiflora'},
#  {'start': 1363, 'end': 1374, 'text': 'D. Novinger'},
#  {'start': 2287, 'end': 2293, 'text': 'Pisces'},
#  {'start': 3208, 'end': 3214, 'text': 'labrid'},
#  {'start': 3338, 'end': 3344, 'text': 'labrid'},
#  {'start': 4656, 'end': 4675, 'text': 'protogynous grouper'},
#  {'start': 9, 'end': 21, 'text': 'DIPTEROCARPS'},
#  {'start': 164, 'end': 171, 'text': 'Hindoos'},
#  {'start': 392, 'end': 399, 'text': 'Hindoos'},
#  {'start': 4646, 'end': 4650, 'text': 'Teak'},
#  {'start': 828, 'end': 835, 'text': 'Vateria'},
#  {'start': 783, 'end': 805, 'text': 'Dipterocarpus sp. aff.'},
#  {'start': 806, 'end': 825, 'text': 'D. turbinato Gaertn'},
#  {'start': 1182, 'end': 1195, 'text': 'D. turbinatus'},
#  {'start': 13, 'end': 26, 'text': 'Euphorbiaceae'},
#  {'start': 366, 'end': 372, 'text': 'molave'},
#  {'start': 1665, 'end': 1673, 'text': 'Imperata'},
#  {'start': 1675, 'end': 1684, 'text': 'Saccharum'},
#  {'start': 880, 'end': 886, 'text': 'Eqwula'},
#  {'start': 2819, 'end': 2839, 'text': 'Gazza mmula, Gunther'},
#  {'start': 2876,
#   'end': 2917,
#   'text': 'Xystsema punctatum (Cuvier & Valenciennes'},
#  {'start': 177, 'end': 191, 'text': 'Pseudorhabdium'},
#  {'start': 176, 'end': 198, 'text': 'Acrotrema lyratum, Hk.'},
#  {'start': 468, 'end': 498, 'text': 'Schumacheria angustifolia, Hk.'},
#  {'start': 644, 'end': 660, 'text': 'Wormia triquetra'},
#  {'start': 1018, 'end': 1040, 'text': 'Limacia cuspidata, Hk.'},
#  {'start': 1252, 'end': 1276, 'text': 'V. Alsodeia virgata, Hk.'},
#  {'start': 1727, 'end': 1748, 'text': 'Aueria Gardneri, Clos'},
#  {'start': 2078, 'end': 2104, 'text': 'Trichadenia zeylanica, Thw'},
#  {'start': 2462, 'end': 2490, 'text': 'Adinandra lasiopetala, Chois'},
#  {'start': 314, 'end': 347, 'text': 'Dipterocarpus polyspermus, Blanco'},
#  {'start': 719, 'end': 725, 'text': 'baucas'},
#  {'start': 1682, 'end': 1690, 'text': 'Pampauga'},
#  {'start': 605, 'end': 611, 'text': 'Todaya'},
#  {'start': 702, 'end': 724, 'text': 'Mus mindorensis Thomas'},
#  {'start': 104, 'end': 110, 'text': 'surdus'},
#  {'start': 207, 'end': 215, 'text': 'Dioscoro'},
#  {'start': 565, 'end': 573, 'text': 'Pandanus'},
#  {'start': 720, 'end': 728, 'text': 'Pandanus'},
#  {'start': 1267, 'end': 1285, 'text': 'Cornufer guentheri'},
#  {'start': 0, 'end': 19, 'text': 'DESTRUCTIVE FISHING'},
#  {'start': 88, 'end': 108, 'text': 'V. lanceaefolia, Bl.'},
#  {'start': 175, 'end': 201, 'text': 'Vateria lanceafolia, Roxb.'},
#  {'start': 305, 'end': 323, 'text': 'V. trigyna, Griff.'},
#  {'start': 644, 'end': 654, 'text': 'Conspectus'}]

# %% [markdown]
# #### Eval on BB task corpus

# %%
PATH_TO_BB_GT = '../corpora/BB_GSC_brat/bb_clean/test'
PATH_TO_BB_PRED = "./output/TAXONERD_MD/BB_pred"

# %%
run_taxonerd(PATH_TO_BB_GT, PATH_TO_BB_PRED)

# %%
get_precision_recall_f1_single_corpus(PATH_TO_BB_PRED, PATH_TO_BB_GT, criterion=exact)
# Out:
# $73.11$ & $77.50$ & $75.24$
#        precision  recall  f1-score
# Taxon   0.731132   0.775  0.752427

# %%
get_precision_recall_f1_single_corpus(PATH_TO_BB_PRED, PATH_TO_BB_GT, criterion=approximate)
# Out:
# $76.42$ & $81.20$ & $78.74$
#        precision   recall  f1-score
# Taxon   0.764151  0.81203  0.787363

# %%
FN, FP, TP = get_FN_FP_TP_single_corpus(PATH_TO_BB_PRED, PATH_TO_BB_GT, criterion=approximate)
FP
# Out:
# [{'start': 19, 'end': 44, 'text': 'L. lactis subsp. cremoris'},
#  {'start': 230, 'end': 255, 'text': 'L. lactis subsp. cremoris'},
#  {'start': 0, 'end': 9, 'text': 'Serotypes'},
#  {'start': 513, 'end': 522, 'text': 'serotypes'},
#  {'start': 41, 'end': 66, 'text': 'Burkholderia pseudomallei'},
#  {'start': 258, 'end': 270, 'text': 'Burkholderia'},
#  {'start': 272, 'end': 297, 'text': 'Pseudomonas) pseudomallei'},
#  {'start': 521, 'end': 529, 'text': 'biotypes'},
#  {'start': 1003, 'end': 1007, 'text': 'LPSs'},
#  {'start': 1021, 'end': 1029, 'text': 'biotypes'},
#  {'start': 1379, 'end': 1396, 'text': 'hyperimmune mouse'},
#  {'start': 365, 'end': 373, 'text': 'Scimudin'},
#  {'start': 46, 'end': 56, 'text': 'Gorgonzola'},
#  {'start': 61, 'end': 69, 'text': 'Scimudin'},
#  {'start': 239, 'end': 249, 'text': 'Gorgonzola'},
#  {'start': 254, 'end': 262, 'text': 'Scimudin'},
#  {'start': 194, 'end': 203, 'text': 'pneumonia'},
#  {'start': 105, 'end': 115, 'text': 'Gorgonzola'},
#  {'start': 130, 'end': 138, 'text': 'Scimudin'},
#  {'start': 414, 'end': 422, 'text': 'Scimudin'},
#  {'start': 513, 'end': 523, 'text': 'Gorgonzola'},
#  {'start': 756, 'end': 764, 'text': 'Scimudin'},
#  {'start': 368, 'end': 383, 'text': 'Gorgonzola rind'},
#  {'start': 530, 'end': 540, 'text': 'Gorgonzola'},
#  {'start': 545, 'end': 553, 'text': 'Scimudin'},
#  {'start': 974, 'end': 982, 'text': 'Scimudin'},
#  {'start': 1001, 'end': 1011, 'text': 'Gorgonzola'},
#  {'start': 349, 'end': 359, 'text': 'Gorgonzola'},
#  {'start': 364, 'end': 372, 'text': 'Scimudin'},
#  {'start': 540, 'end': 550, 'text': 'Gorgonzola'},
#  {'start': 552, 'end': 560, 'text': 'Scimudin'},
#  {'start': 207, 'end': 212, 'text': 'cocci'},
#  {'start': 185, 'end': 221, 'text': 'Bacillus thuringiensis serovar sotto'},
#  {'start': 285, 'end': 298, 'text': 'mosquitocidal'},
#  {'start': 372, 'end': 385, 'text': 'mosquitocidal'},
#  {'start': 459, 'end': 481, 'text': 'Culex pipiens molestus'},
#  {'start': 879, 'end': 889, 'text': 'R. conorii'},
#  {'start': 166, 'end': 188, 'text': 'Salmonella typhimurium'},
#  {'start': 42, 'end': 67, 'text': 'L. lactis subsp. cremoris'},
#  {'start': 166, 'end': 181, 'text': 'C. ammoniagenes'},
#  {'start': 119, 'end': 129, 'text': 'Gorgonzola'},
#  {'start': 786, 'end': 799, 'text': 'diarrheagenic'},
#  {'start': 1004, 'end': 1017, 'text': 'diarrheagenic'},
#  {'start': 2031, 'end': 2042, 'text': 'A rotavirus'},
#  {'start': 2044, 'end': 2057, 'text': 'diarrheagenic'},
#  {'start': 261, 'end': 276, 'text': 'L. lactis B1157'},
#  {'start': 574, 'end': 581, 'text': 'monkeys'},
#  {'start': 604, 'end': 611, 'text': 'monkeys'},
#  {'start': 86, 'end': 102, 'text': 'metalloregulator'},
#  {'start': 0, 'end': 28, 'text': 'Corynebacterium ammoniagenes'},
#  {'start': 39, 'end': 57, 'text': 'Lactococcus lactis'},
#  {'start': 1286, 'end': 1295, 'text': 'huscFv1E4'},
#  {'start': 1496, 'end': 1505, 'text': 'huscFv1E4'},
#  {'start': 1599, 'end': 1608, 'text': 'huscFv1E4'},
#  {'start': 144, 'end': 152, 'text': 'Scimudin'},
#  {'start': 364, 'end': 372, 'text': 'Scimudin'},
#  {'start': 377, 'end': 387, 'text': 'Gorgonzola'},
#  {'start': 490, 'end': 498, 'text': 'Scimudin'},
#  {'start': 653, 'end': 661, 'text': 'Scimudin'},
#  {'start': 682, 'end': 692, 'text': 'Gorgonzola'},
#  {'start': 761, 'end': 771, 'text': 'Gorgonzola'},
#  {'start': 781, 'end': 789, 'text': 'Scimudin'},
#  {'start': 58, 'end': 77, 'text': 'Lactobacillus casei'},
#  {'start': 85, 'end': 92, 'text': 'Shirota'},
#  {'start': 277, 'end': 296, 'text': 'Lactobacillus casei'},
#  {'start': 304, 'end': 311, 'text': 'Shirota'},
#  {'start': 21, 'end': 43, 'text': 'Haemophilus influenzae'},
#  {'start': 156, 'end': 178, 'text': 'Haemophilus influenzae'},
#  {'start': 224, 'end': 259, 'text': 'Adoratopsylla antiquorum antiquorum'},
#  {'start': 261, 'end': 288, 'text': 'Ctenocephalides felis felis'},
#  {'start': 290, 'end': 306, 'text': 'Polygenis atopus'},
#  {'start': 308, 'end': 325, 'text': 'Polygenis rimatus'},
#  {'start': 327, 'end': 352, 'text': 'Polygenis roberti roberti'},
#  {'start': 354, 'end': 370, 'text': 'Polygenis tripus'},
#  {'start': 372, 'end': 395, 'text': 'Rhopalopsyllus lugubris'},
#  {'start': 401, 'end': 427, 'text': 'Rhopalopsyllus lutzi lutzi'},
#  {'start': 453, 'end': 473, 'text': 'Amblyomma aureolatum'},
#  {'start': 475, 'end': 495, 'text': 'Amblyomma cajennense'},
#  {'start': 497, 'end': 516, 'text': 'Amblyomma dubitatum'},
#  {'start': 518, 'end': 534, 'text': 'Ixodes loricatus'},
#  {'start': 540, 'end': 564, 'text': 'Rhipicephalus sanguineus'},
#  {'start': 964, 'end': 971, 'text': 'opossum'},
#  {'start': 978, 'end': 983, 'text': 'horse'},
#  {'start': 1237, 'end': 1242, 'text': 'horse'},
#  {'start': 2189, 'end': 2202, 'text': 'F. tularensis'},
#  {'start': 2203, 'end': 2217, 'text': 'ssp tularensis'},
#  {'start': 2422, 'end': 2427, 'text': 'HB-19'},
#  {'start': 212, 'end': 222, 'text': 'Gorgonzola'},
#  {'start': 391, 'end': 399, 'text': 'Scimudin'},
#  {'start': 340, 'end': 343, 'text': 'LGV'},
#  {'start': 736, 'end': 758, 'text': 'LGV associated serovar'},
#  {'start': 780, 'end': 783, 'text': 'LGV'},
#  {'start': 58, 'end': 71, 'text': 'Perdix perdix'},
#  {'start': 173, 'end': 186, 'text': 'Perdix perdix'},
#  {'start': 487, 'end': 491, 'text': 'YopP'},
#  {'start': 1190, 'end': 1199, 'text': 'Y. pestis'},
#  {'start': 1207, 'end': 1211, 'text': 'KIM6'},
#  {'start': 27, 'end': 43, 'text': 'Gouda or Cheddar'},
#  {'start': 632, 'end': 642, 'text': 'Probiotics'},
#  {'start': 417, 'end': 438, 'text': 'M. fortuitum-chelonei'}]
