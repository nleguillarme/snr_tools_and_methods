# %%
import os

# %% [markdown]
# ### Build TAXONFINDER docker image

# %%
import docker

# %%
DOCKERFILE_PATH = "../images/TaxonFinder"

client = docker.from_env()
client.images.build(path=DOCKERFILE_PATH, tag="taxonfinder:latest")
# Out:
# (<Image: 'taxonfinder:latest'>, <itertools._tee at 0x7f15aa65fc00>)

# %% [markdown]
# ### Run TAXONFINDER and parse results

# %%
import shutil

def run_taxonfinder(input_dir, output_dir):
    if os.path.isdir(output_dir):
        shutil.rmtree(output_dir)
    os.makedirs(output_dir)
    volume = {os.path.abspath(input_dir): {'bind': '/home/taxonfinder/corpus', 'mode': 'ro'}}
    client = docker.from_env()
    image = client.images.get("taxonfinder:latest")
    response = client.containers.run(image, "nodejs taxonfinder.js", volumes=volume, remove=True)
    return response.decode("utf-8").split("\n")[2:]

# %%
import yaml
import pandas as pd
import shutil

def taxonfinder_tags_to_df(tags):
    data = yaml.load(tags, Loader=yaml.BaseLoader)
    data = [{"start": item["offsets"][0], "end": item["offsets"][1], "name" : item["name"]} for item in data]
    return pd.DataFrame(data)

def parse_taxonfinder(response, output_dir):
    if os.path.isdir(output_dir):
        shutil.rmtree(output_dir)
    os.makedirs(output_dir)
    tags = ""
    for item in response:
        if item.endswith(".txt"):
            document = os.path.basename(item)
        else:
            tags += item
        if item.endswith("]"):
            doc_ann = taxonfinder_tags_to_df(tags)
            doc_ann = doc_ann.rename('T{}'.format)
            doc_ann.insert(0, "type", ["Taxon"]*doc_ann.shape[0])
            ann_filename = document.split(".")[0]+".ann"
            doc_ann.to_csv(os.path.join(output_dir, ann_filename), sep="\t", header=False)
            tags = ""

# %% [markdown]
# ### Eval TAXONFINDER on test corpora

# %%
from eval_utils import *

# %% [markdown]
# #### Eval on LINNAEUS GSC

# %%
PATH_TO_LINNAEUS_GT = '../corpora/LINNAEUS_GSC_brat/linnaeus_clean/test'
PATH_TO_LINNAEUS_PRED = "./output/TAXONFINDER/LINNAEUS_pred"

# %%
response = run_taxonfinder(PATH_TO_LINNAEUS_GT, PATH_TO_LINNAEUS_PRED)
parse_taxonfinder(response, PATH_TO_LINNAEUS_PRED)

# %%
get_precision_recall_f1_single_corpus(PATH_TO_LINNAEUS_PRED, PATH_TO_LINNAEUS_GT, criterion=exact)
# Out:
# $86.83$ & $20.84$ & $33.61$
#        precision    recall  f1-score
# Taxon   0.868327  0.208369  0.336088

# %%
get_precision_recall_f1_single_corpus(PATH_TO_LINNAEUS_PRED, PATH_TO_LINNAEUS_GT, criterion=approximate)
# Out:
# $86.83$ & $20.84$ & $33.61$
#        precision    recall  f1-score
# Taxon   0.868327  0.208369  0.336088

# %%
FN, FP, TP = get_FN_FP_TP_single_corpus(PATH_TO_LINNAEUS_PRED, PATH_TO_LINNAEUS_GT, criterion=exact)
FP
# Out:
# [{'start': 0, 'end': 9, 'text': 'Cytotoxic'},
#  {'start': 786, 'end': 795, 'text': 'Cytotoxic'},
#  {'start': 3682, 'end': 3691, 'text': 'Cytotoxic'},
#  {'start': 6831, 'end': 6840, 'text': 'Cytotoxic'},
#  {'start': 10442, 'end': 10450, 'text': 'Capsicum'},
#  {'start': 10814, 'end': 10823, 'text': 'Echinacea'},
#  {'start': 2814, 'end': 2819, 'text': 'Magos'},
#  {'start': 20832, 'end': 20837, 'text': 'Magos'},
#  {'start': 26118, 'end': 26123, 'text': 'Magos'},
#  {'start': 194, 'end': 201, 'text': 'Diptera'},
#  {'start': 203, 'end': 214, 'text': 'Psychodidae'},
#  {'start': 1478, 'end': 1488, 'text': 'Drosophila'},
#  {'start': 1663, 'end': 1676, 'text': 'Phlebotominae'},
#  {'start': 1998, 'end': 2008, 'text': 'Leishmania'},
#  {'start': 3028, 'end': 3038, 'text': 'Drosophila'},
#  {'start': 3506, 'end': 3516, 'text': 'Drosophila'},
#  {'start': 3521, 'end': 3531, 'text': 'Bractocera'},
#  {'start': 3653, 'end': 3663, 'text': 'Drosophila'},
#  {'start': 3801, 'end': 3811, 'text': 'Drosophila'},
#  {'start': 8156, 'end': 8165, 'text': 'Nyssomyia'},
#  {'start': 18824, 'end': 18834, 'text': 'Drosophila'},
#  {'start': 316, 'end': 321, 'text': 'Culex'},
#  {'start': 1008, 'end': 1013, 'text': 'Culex'},
#  {'start': 1314, 'end': 1319, 'text': 'Culex'},
#  {'start': 2452, 'end': 2457, 'text': 'Culex'},
#  {'start': 2617, 'end': 2622, 'text': 'Culex'},
#  {'start': 6669, 'end': 6686, 'text': 'Culex annulus'},
#  {'start': 6942, 'end': 6947, 'text': 'Culex'},
#  {'start': 8142, 'end': 8147, 'text': 'Culex'},
#  {'start': 8359, 'end': 8364, 'text': 'Aedes'},
#  {'start': 8848, 'end': 8878, 'text': 'Rhipicephalus turanicus'},
#  {'start': 9266, 'end': 9271, 'text': 'Aedes'},
#  {'start': 9273, 'end': 9283, 'text': 'Psorophora'},
#  {'start': 10189, 'end': 10194, 'text': 'Culex'},
#  {'start': 10666, 'end': 10671, 'text': 'Culex'},
#  {'start': 1498, 'end': 1514, 'text': 'Burkholderiaceae'},
#  {'start': 12065, 'end': 12077, 'text': 'Burkholderia'}]

# %% [markdown]
# #### Eval on S800 GSC

# %%
PATH_TO_S800_GT = '../corpora/S800_GSC_brat/s800/test'
PATH_TO_S800_PRED = "./output/TAXONFINDER/S800_pred"

# %%
response = run_taxonfinder(PATH_TO_S800_GT, PATH_TO_S800_PRED)
parse_taxonfinder(response, PATH_TO_S800_PRED)

# %%
get_precision_recall_f1_single_corpus(PATH_TO_S800_PRED, PATH_TO_S800_GT, criterion=exact)
# Out:
# $57.04$ & $40.68$ & $47.49$
#        precision   recall  f1-score
# Taxon   0.570384  0.40678  0.474886

# %%
get_precision_recall_f1_single_corpus(PATH_TO_S800_PRED, PATH_TO_S800_GT, criterion=approximate)
# Out:
# $57.04$ & $40.68$ & $47.49$
#        precision   recall  f1-score
# Taxon   0.570384  0.40678  0.474886

# %%
FN, FP, TP = get_FN_FP_TP_single_corpus(PATH_TO_S800_PRED, PATH_TO_S800_GT, criterion=exact)
FN
# Out:
# [{'start': 35, 'end': 64, 'text': 'porcine endogenous retrovirus'},
#  {'start': 166, 'end': 197, 'text': 'Porcine endogenous retroviruses'},
#  {'start': 199, 'end': 204, 'text': 'PERVs'},
#  {'start': 314, 'end': 319, 'text': 'human'},
#  {'start': 381, 'end': 385, 'text': 'pigs'},
#  {'start': 394, 'end': 399, 'text': 'PERVs'},
#  {'start': 630, 'end': 640, 'text': 'retroviral'},
#  {'start': 665, 'end': 669, 'text': 'PERV'},
#  {'start': 787, 'end': 793, 'text': 'PERV-B'},
#  {'start': 909, 'end': 919, 'text': 'retroviral'},
#  {'start': 984, 'end': 990, 'text': 'PERV-B'},
#  {'start': 1135, 'end': 1141, 'text': 'PERV-A'},
#  {'start': 173, 'end': 178, 'text': 'M2(T)'},
#  {'start': 327, 'end': 332, 'text': 'M2(T)'},
#  {'start': 550, 'end': 555, 'text': 'M2(T)'},
#  {'start': 635, 'end': 666, 'text': 'Methanobacterium veterum MK4(T)'},
#  {'start': 697, 'end': 707, 'text': 'DSM 863(T)'},
#  {'start': 827, 'end': 832, 'text': 'M2(T)'},
#  {'start': 880, 'end': 885, 'text': 'M2(T)'},
#  {'start': 981, 'end': 986, 'text': 'M2(T)'},
#  {'start': 48, 'end': 53, 'text': 'maize'},
#  {'start': 273, 'end': 278, 'text': 'maize'},
#  {'start': 427, 'end': 433, 'text': 'fungal'},
#  {'start': 717, 'end': 727, 'text': 'great tits'},
#  {'start': 729, 'end': 743, 'text': 'Parus major L.'},
#  {'start': 107, 'end': 121, 'text': 'Chromera velia'},
#  {'start': 125, 'end': 139, 'text': 'Chromera velia'},
#  {'start': 513, 'end': 521, 'text': 'sycamore'},
#  {'start': 845, 'end': 862, 'text': 'Chlorella strains'},
#  {'start': 40, 'end': 58, 'text': 'Tuber melanosporum'},
#  {'start': 471, 'end': 489, 'text': 'Tuber melanosporum'},
#  {'start': 611, 'end': 617, 'text': 'yeasts'},
#  {'start': 1051, 'end': 1057, 'text': 'yeasts'},
#  {'start': 707, 'end': 727, 'text': 'silver leaf whitefly'},
#  {'start': 0,
#   'end': 45,
#   'text': 'Cotterillia bromelicola nov. gen., nov. spec.'},
#  {'start': 175,
#   'end': 220,
#   'text': 'Cotterillia bromelicola nov. gen., nov. spec.'},
#  {'start': 377, 'end': 388, 'text': 'Cotterillia'},
#  {'start': 487, 'end': 498, 'text': 'Cotterillia'},
#  {'start': 799, 'end': 822, 'text': 'Cotterillia bromelicola'},
#  {'start': 1053, 'end': 1064, 'text': 'Cotterillia'},
#  {'start': 1290, 'end': 1301, 'text': 'Cotterillia'},
#  {'start': 110, 'end': 136, 'text': 'Vesicular stomatitis virus'},
#  {'start': 138, 'end': 141, 'text': 'VSV'},
#  {'start': 261, 'end': 264, 'text': 'VSV'},
#  {'start': 481, 'end': 484, 'text': 'VSV'},
#  {'start': 1508, 'end': 1511, 'text': 'VSV'},
#  {'start': 1669, 'end': 1672, 'text': 'VSV'},
#  {'start': 365, 'end': 377, 'text': 'E. amylovora'},
#  {'start': 47, 'end': 73, 'text': 'Rhizobium sp. strain LPU83'},
#  {'start': 662, 'end': 688, 'text': 'Rhizobium sp. strain LPU83'},
#  {'start': 733, 'end': 740, 'text': 'alfalfa'},
#  {'start': 752, 'end': 772, 'text': 'Leucena leucocephala'},
#  {'start': 896, 'end': 903, 'text': 'alfalfa'},
#  {'start': 1074, 'end': 1104, 'text': 'Rhizobium mongolense USDA 1844'},
#  {'start': 1127, 'end': 1132, 'text': 'LPU83'},
#  {'start': 1228, 'end': 1233, 'text': 'LPU83'},
#  {'start': 1254, 'end': 1272, 'text': 'R. mongolense 1844'},
#  {'start': 1314, 'end': 1340, 'text': 'Rhizobium sp. strain LPU83'},
#  {'start': 1366, 'end': 1373, 'text': 'alfalfa'},
#  {'start': 1630, 'end': 1635, 'text': 'LPU83'},
#  {'start': 1748, 'end': 1755, 'text': 'LPU83-H'},
#  {'start': 1851, 'end': 1856, 'text': 'LPU83'},
#  {'start': 1878, 'end': 1885, 'text': 'alfalfa'},
#  {'start': 48, 'end': 75, 'text': 'giant Australian cuttlefish'},
#  {'start': 76, 'end': 87, 'text': 'Sepia apama'},
#  {'start': 710, 'end': 737, 'text': 'giant Australian cuttlefish'},
#  {'start': 738, 'end': 749, 'text': 'Sepia apama'},
#  {'start': 69, 'end': 86, 'text': 'hepatitis A virus'},
#  {'start': 147, 'end': 164, 'text': 'hepatitis A virus'},
#  {'start': 166, 'end': 169, 'text': 'HAV'},
#  {'start': 192, 'end': 196, 'text': 'hens'},
#  {'start': 242, 'end': 245, 'text': 'HAV'},
#  {'start': 258, 'end': 261, 'text': 'HAV'},
#  {'start': 497, 'end': 500, 'text': 'HAV'},
#  {'start': 836, 'end': 839, 'text': 'HAV'},
#  {'start': 915, 'end': 918, 'text': 'HAV'},
#  {'start': 1022, 'end': 1025, 'text': 'HAV'},
#  {'start': 1118, 'end': 1121, 'text': 'HAV'},
#  {'start': 1131, 'end': 1135, 'text': 'hens'},
#  {'start': 1300, 'end': 1317, 'text': 'hepatitis A virus'},
#  {'start': 488, 'end': 496, 'text': 'rapeseed'},
#  {'start': 1451, 'end': 1458, 'text': 'tobacco'},
#  {'start': 507, 'end': 512, 'text': 'human'},
#  {'start': 792, 'end': 799, 'text': 'tobacco'},
#  {'start': 1137, 'end': 1144, 'text': 'tobacco'},
#  {'start': 1215, 'end': 1222, 'text': 'tobacco'},
#  {'start': 298, 'end': 307, 'text': 'orf virus'},
#  {'start': 309, 'end': 313, 'text': 'ORFV'},
#  {'start': 331, 'end': 335, 'text': 'ORFV'},
#  {'start': 27, 'end': 35, 'text': 'broccoli'},
#  {'start': 126, 'end': 134, 'text': 'broccoli'},
#  {'start': 632, 'end': 640, 'text': 'broccoli'},
#  {'start': 737, 'end': 745, 'text': 'broccoli'},
#  {'start': 1346, 'end': 1354, 'text': 'broccoli'},
#  {'start': 1477, 'end': 1482, 'text': 'human'},
#  {'start': 1267, 'end': 1275, 'text': 'wax moth'},
#  {'start': 85, 'end': 100, 'text': 'cotton bollworm'},
#  {'start': 112, 'end': 129, 'text': 'Arctic springtail'},
#  {'start': 29, 'end': 64, 'text': 'human immunodeficiency virus type 1'},
#  {'start': 110, 'end': 145, 'text': 'Human immunodeficiency virus type 1'},
#  {'start': 147, 'end': 152, 'text': 'HIV-1'},
#  {'start': 271, 'end': 276, 'text': 'HIV-1'},
#  {'start': 590, 'end': 595, 'text': 'HIV-1'},
#  {'start': 675, 'end': 680, 'text': 'HIV-1'},
#  {'start': 783, 'end': 788, 'text': 'HIV-1'},
#  {'start': 930, 'end': 935, 'text': 'HIV-1'},
#  {'start': 1037, 'end': 1042, 'text': 'HIV-1'},
#  {'start': 1184, 'end': 1189, 'text': 'HIV-1'},
#  {'start': 1303, 'end': 1308, 'text': 'HIV-1'},
#  {'start': 1418, 'end': 1423, 'text': 'HIV-1'},
#  {'start': 1580, 'end': 1585, 'text': 'HIV-1'},
#  {'start': 413, 'end': 428, 'text': 'influenza virus'},
#  {'start': 493, 'end': 498, 'text': 'human'},
#  {'start': 1630, 'end': 1645, 'text': 'influenza virus'},
#  {'start': 1656, 'end': 1673, 'text': 'hepatitis C virus'},
#  {'start': 1816, 'end': 1821, 'text': 'human'},
#  {'start': 0, 'end': 17, 'text': 'Hepatitis C virus'},
#  {'start': 168, 'end': 185, 'text': 'hepatitis C virus'},
#  {'start': 187, 'end': 190, 'text': 'HCV'},
#  {'start': 346, 'end': 349, 'text': 'HCV'},
#  {'start': 56, 'end': 60, 'text': 'H1N1'},
#  {'start': 65, 'end': 87, 'text': 'H5 influenza a viruses'},
#  {'start': 91, 'end': 95, 'text': 'mice'},
#  {'start': 99, 'end': 118, 'text': 'Influenza A viruses'},
#  {'start': 123, 'end': 128, 'text': 'human'},
#  {'start': 228, 'end': 232, 'text': 'H1N1'},
#  {'start': 287, 'end': 291, 'text': 'H1N1'},
#  {'start': 301, 'end': 308, 'text': 'H1N1pdm'},
#  {'start': 310, 'end': 327, 'text': 'influenza A virus'},
#  {'start': 383, 'end': 388, 'text': 'human'},
#  {'start': 401, 'end': 406, 'text': 'swine'},
#  {'start': 487, 'end': 502, 'text': 'H1N1pdm viruses'},
#  {'start': 506, 'end': 512, 'text': 'humans'},
#  {'start': 671, 'end': 676, 'text': 'mouse'},
#  {'start': 831, 'end': 844, 'text': 'H1N1pdm virus'},
#  {'start': 893, 'end': 898, 'text': 'human'},
#  {'start': 928, 'end': 933, 'text': 'mouse'},
#  {'start': 1096, 'end': 1101, 'text': 'mouse'},
#  {'start': 1271, 'end': 1286, 'text': 'H1N1pdm viruses'},
#  {'start': 1421, 'end': 1431, 'text': 'H5 viruses'},
#  {'start': 1435, 'end': 1439, 'text': 'mice'},
#  {'start': 1500, 'end': 1519, 'text': 'influenza A viruses'},
#  {'start': 1703, 'end': 1722, 'text': 'influenza A viruses'},
#  {'start': 1730, 'end': 1735, 'text': 'mouse'},
#  {'start': 1904, 'end': 1909, 'text': 'human'},
#  {'start': 1910, 'end': 1917, 'text': 'H1N1pdm'},
#  {'start': 1106, 'end': 1111, 'text': 'human'},
#  {'start': 27, 'end': 32, 'text': 'maize'},
#  {'start': 555, 'end': 560, 'text': 'maize'},
#  {'start': 380, 'end': 403, 'text': 'K-12 strains of E. coli'},
#  {'start': 987, 'end': 999, 'text': 'E. coli K-12'},
#  {'start': 1102, 'end': 1106, 'text': 'K-12'},
#  {'start': 1325, 'end': 1334, 'text': 'E. coli B'},
#  {'start': 1556, 'end': 1568, 'text': 'E. coli K-12'},
#  {'start': 80, 'end': 110, 'text': 'pandemic influenza A/H1N1 2009'},
#  {'start': 112, 'end': 137, 'text': 'seasonal influenza A/H1N1'},
#  {'start': 143, 'end': 176, 'text': 'seasonal influenza A/H3N2 viruses'},
#  {'start': 180,
#   'end': 228,
#   'text': 'Pandemic influenza A/H1N1 2009 (A/H1N1pdm) virus'},
#  {'start': 359, 'end': 374, 'text': 'A/H1N1pdm virus'},
#  {'start': 534, 'end': 549, 'text': 'A/H1N1pdm virus'},
#  {'start': 600, 'end': 605, 'text': 'human'},
#  {'start': 606, 'end': 621, 'text': 'seasonal A/H1N1'},
#  {'start': 645, 'end': 669, 'text': 'A/H3N2 influenza viruses'},
#  {'start': 992, 'end': 1018, 'text': 'viral strains of A/H1N1pdm'},
#  {'start': 1028, 'end': 1054, 'text': 'A/Aichi/472/2009 (H1N1)pdm'},
#  {'start': 1059, 'end': 1084, 'text': 'A/Sakai/89/2009 (H1N1)pdm'},
#  {'start': 1378, 'end': 1385, 'text': 'A/H1pdm'},
#  {'start': 1387, 'end': 1391, 'text': 'A/H3'},
#  {'start': 1397, 'end': 1401, 'text': 'A/H1'},
#  {'start': 1452, 'end': 1471, 'text': 'influenza A viruses'},
#  {'start': 1610, 'end': 1627, 'text': 'influenza viruses'},
#  {'start': 1662, 'end': 1679, 'text': 'influenza viruses'},
#  {'start': 70, 'end': 79, 'text': 'West Nile'},
#  {'start': 157, 'end': 165, 'text': 'WN virus'},
#  {'start': 405, 'end': 432, 'text': 'Japanese encephalitis virus'},
#  {'start': 493, 'end': 495, 'text': 'WN'},
#  {'start': 682, 'end': 684, 'text': 'WN'},
#  {'start': 899, 'end': 902, 'text': 'WNV'},
#  {'start': 1265, 'end': 1268, 'text': 'WNV'},
#  {'start': 1274, 'end': 1277, 'text': 'JEV'},
#  {'start': 91, 'end': 108, 'text': 'American dog tick'},
#  {'start': 343, 'end': 360, 'text': 'American dog tick'},
#  {'start': 56, 'end': 59, 'text': 'HIV'},
#  {'start': 131, 'end': 134, 'text': 'HIV'},
#  {'start': 266, 'end': 271, 'text': 'human'},
#  {'start': 344, 'end': 349, 'text': 'HIV-1'},
#  {'start': 353, 'end': 364, 'text': 'chimpanzees'},
#  {'start': 434, 'end': 439, 'text': 'HIV-1'},
#  {'start': 818, 'end': 823, 'text': 'HIV-1'},
#  {'start': 875, 'end': 880, 'text': 'human'},
#  {'start': 1151, 'end': 1156, 'text': 'HIV-1'},
#  {'start': 46, 'end': 64, 'text': 'Mexican palo verde'},
#  {'start': 234, 'end': 252, 'text': 'Mexican palo verde'},
#  {'start': 1260, 'end': 1265, 'text': 'moose'},
#  {'start': 52, 'end': 78, 'text': 'Glassy-Winged Sharpshooter'},
#  {'start': 137, 'end': 163, 'text': 'glassy-winged sharpshooter'},
#  {'start': 165, 'end': 197, 'text': 'Homalodisca vitripennis (Germar)'},
#  {'start': 479, 'end': 505, 'text': 'Xylella fastidiosa (Wells)'},
#  {'start': 816, 'end': 821, 'text': 'Yeast'},
#  {'start': 16, 'end': 52, 'text': 'Fusarium graminearum species complex'},
#  {'start': 58, 'end': 63, 'text': 'wheat'},
#  {'start': 65, 'end': 71, 'text': 'barley'},
#  {'start': 76, 'end': 81, 'text': 'maize'},
#  {'start': 243, 'end': 279, 'text': 'Fusarium graminearum species complex'},
#  {'start': 281, 'end': 285, 'text': 'FGSC'},
#  {'start': 311, 'end': 316, 'text': 'wheat'},
#  {'start': 318, 'end': 324, 'text': 'barley'},
#  {'start': 329, 'end': 334, 'text': 'maize'},
#  {'start': 656, 'end': 660, 'text': 'FGSC'},
#  {'start': 715, 'end': 720, 'text': 'maize'},
#  {'start': 766, 'end': 771, 'text': 'wheat'},
#  {'start': 775, 'end': 781, 'text': 'barley'},
#  {'start': 846, 'end': 850, 'text': 'FGSC'},
#  {'start': 883, 'end': 888, 'text': 'wheat'},
#  {'start': 893, 'end': 899, 'text': 'barley'},
#  {'start': 963, 'end': 968, 'text': 'maize'},
#  {'start': 1077, 'end': 1092, 'text': 'Fusariumboothii'},
#  {'start': 1120, 'end': 1125, 'text': 'maize'},
#  {'start': 1451, 'end': 1455, 'text': 'FGSC'},
#  {'start': 1527, 'end': 1532, 'text': 'maize'},
#  {'start': 1564, 'end': 1568, 'text': 'FGSC'},
#  {'start': 0, 'end': 32, 'text': 'Nocardioides caricicola sp. nov.'},
#  {'start': 189, 'end': 195, 'text': 'YC6903'},
#  {'start': 398, 'end': 404, 'text': 'YC6903'},
#  {'start': 525, 'end': 531, 'text': 'YC6903'},
#  {'start': 607, 'end': 613, 'text': 'YC6903'},
#  {'start': 645, 'end': 677, 'text': 'Nocardioides pyridinolyticus OS4'},
#  {'start': 725, 'end': 756, 'text': 'Nocardioides dokdonensis FR1436'},
#  {'start': 770, 'end': 798, 'text': 'Nocardioides aquiterrae GW-9'},
#  {'start': 815, 'end': 846, 'text': 'Nocardioides hankookensis DS-30'},
#  {'start': 1032, 'end': 1038, 'text': 'YC6903'},
#  {'start': 1046, 'end': 1068, 'text': 'N. pyridinolyticus OS4'},
#  {'start': 1136, 'end': 1142, 'text': 'YC6903'},
#  {'start': 1280, 'end': 1286, 'text': 'YC6903'},
#  {'start': 1363, 'end': 1395, 'text': 'Nocardioides caricicola sp. nov.'},
#  {'start': 1428, 'end': 1434, 'text': 'YC6903'},
#  {'start': 196, 'end': 220, 'text': 'B. burgdorferi strain 31'},
#  {'start': 75, 'end': 80, 'text': 'wheat'},
#  {'start': 148, 'end': 153, 'text': 'wheat'},
#  {'start': 468, 'end': 473, 'text': 'wheat'},
#  {'start': 34, 'end': 42, 'text': 'silkworm'},
#  {'start': 426, 'end': 434, 'text': 'silkworm'},
#  {'start': 449, 'end': 457, 'text': 'silkworm'},
#  {'start': 17, 'end': 52, 'text': 'transmissible gastroenteritis virus'},
#  {'start': 163, 'end': 169, 'text': 'rabbit'},
#  {'start': 213, 'end': 248, 'text': 'transmissible gastroenteritis virus'},
#  {'start': 250, 'end': 254, 'text': 'TGEV'},
#  {'start': 366,
#   'end': 411,
#   'text': 'severe acute respiratory syndrome coronavirus'},
#  {'start': 436, 'end': 440, 'text': 'TGEV'},
#  {'start': 530, 'end': 534, 'text': 'TGEV'},
#  {'start': 650, 'end': 656, 'text': 'rabbit'},
#  {'start': 812, 'end': 816, 'text': 'TGEV'},
#  {'start': 88, 'end': 107, 'text': 'betaproteobacterium'},
#  {'start': 207, 'end': 212, 'text': '6C(T)'},
#  {'start': 941, 'end': 946, 'text': '6C(T)'},
#  {'start': 1071, 'end': 1083, 'text': 'DSM 18155(T)'},
#  {'start': 1112, 'end': 1124, 'text': 'DSM 18570(T)'},
#  {'start': 1163, 'end': 1168, 'text': '6C(T)'},
#  {'start': 1194, 'end': 1206, 'text': 'DSM 18155(T)'},
#  {'start': 1235, 'end': 1247, 'text': 'DSM 18570(T)'},
#  {'start': 1363, 'end': 1368, 'text': '6C(T)'},
#  {'start': 1504, 'end': 1509, 'text': '6C(T)'},
#  {'start': 1512, 'end': 1524, 'text': 'DSM 21436(T)'},
#  {'start': 1526, 'end': 1538, 'text': 'JCM 16107(T)'},
#  {'start': 81, 'end': 96, 'text': 'Asian elephants'},
#  {'start': 185, 'end': 200, 'text': 'Asian elephants'},
#  {'start': 89, 'end': 106, 'text': 'white-footed mice'},
#  {'start': 407, 'end': 424, 'text': 'white-footed mice'},
#  {'start': 536, 'end': 553, 'text': 'White-footed mice'},
#  {'start': 740, 'end': 757, 'text': 'white-footed mice'},
#  {'start': 966, 'end': 971, 'text': 'human'},
#  {'start': 2071, 'end': 2088, 'text': 'white-footed mice'},
#  {'start': 275, 'end': 281, 'text': 'humans'},
#  {'start': 97, 'end': 108, 'text': 'coho salmon'},
#  {'start': 113, 'end': 128, 'text': 'steelhead trout'},
#  {'start': 1072, 'end': 1081, 'text': 'steelhead'},
#  {'start': 1086, 'end': 1097, 'text': 'coho salmon'},
#  {'start': 1400, 'end': 1415, 'text': 'steelhead trout'},
#  {'start': 1420, 'end': 1431, 'text': 'coho salmon'},
#  {'start': 1499, 'end': 1508, 'text': 'steelhead'},
#  {'start': 1574, 'end': 1578, 'text': 'coho'},
#  {'start': 1806, 'end': 1815, 'text': 'steelhead'},
#  {'start': 1950, 'end': 1961, 'text': 'brook trout'},
#  {'start': 1966, 'end': 1981, 'text': 'Atlantic salmon'},
#  {'start': 1986, 'end': 1997, 'text': 'brook trout'},
#  {'start': 603,
#   'end': 646,
#   'text': 'Paraclausilocola constricta n. gen., n. sp.'},
#  {'start': 652, 'end': 684, 'text': 'Paraclausilocola elongata n. sp.'},
#  {'start': 467, 'end': 470, 'text': 'HIV'},
#  {'start': 625, 'end': 628, 'text': 'HIV'},
#  {'start': 913, 'end': 930, 'text': 'Chikungunya virus'},
#  {'start': 1050, 'end': 1061, 'text': 'hepatitis A'},
#  {'start': 1066, 'end': 1075, 'text': 'E viruses'},
#  {'start': 576, 'end': 587, 'text': 'house mouse'},
#  {'start': 824, 'end': 829, 'text': 'mouse'},
#  {'start': 858, 'end': 863, 'text': 'mouse'},
#  {'start': 956, 'end': 962, 'text': 'peanut'},
#  {'start': 1051, 'end': 1057, 'text': 'peanut'},
#  {'start': 1380, 'end': 1384, 'text': 'mice'},
#  {'start': 1566, 'end': 1571, 'text': 'Mouse'},
#  {'start': 1898, 'end': 1902, 'text': 'mice'},
#  {'start': 616, 'end': 621, 'text': 'human'},
#  {'start': 116, 'end': 129, 'text': 'silkworm moth'},
#  {'start': 271, 'end': 284, 'text': 'silkworm moth'},
#  {'start': 517, 'end': 525, 'text': 'silkworm'},
#  {'start': 828, 'end': 836, 'text': 'silkworm'},
#  {'start': 43, 'end': 60, 'text': 'influenza A virus'},
#  {'start': 203, 'end': 220, 'text': 'influenza A virus'},
#  {'start': 439, 'end': 448, 'text': 'influenza'},
#  {'start': 449, 'end': 483, 'text': 'A/Duck/Hubei/L-1/2004 (H5N1) virus'},
#  {'start': 499, 'end': 504, 'text': 'human'},
#  {'start': 603, 'end': 607, 'text': 'H5N1'},
#  {'start': 861, 'end': 878, 'text': 'influenza A virus'},
#  {'start': 890, 'end': 895, 'text': 'human'},
#  {'start': 1031,
#   'end': 1076,
#   'text': 'swine-origin influenza A virus (S-OIV) (H1N1)'},
#  {'start': 1301, 'end': 1318, 'text': 'influenza A virus'},
#  {'start': 109, 'end': 114, 'text': 'human'},
#  {'start': 405, 'end': 410, 'text': 'human'},
#  {'start': 1178, 'end': 1183, 'text': 'wheat'},
#  {'start': 248, 'end': 254, 'text': 'IL1403'},
#  {'start': 0, 'end': 30, 'text': 'Streptococcus ursoris sp. nov.'},
#  {'start': 538, 'end': 568, 'text': 'Streptococcus ratti ATCC 19645'},
#  {'start': 986, 'end': 1016, 'text': 'Streptococcus ursoris sp. nov.'},
#  {'start': 1036, 'end': 1046, 'text': 'S. ursoris'},
#  {'start': 1050, 'end': 1061, 'text': 'NUM 1615(T)'},
#  {'start': 98, 'end': 114, 'text': 'influenza A H1N1'},
#  {'start': 724, 'end': 743, 'text': 'influenza A viruses'},
#  {'start': 772, 'end': 788, 'text': 'influenza A H1N1'},
#  {'start': 830, 'end': 846, 'text': 'influenza A H1N1'},
#  {'start': 947, 'end': 958, 'text': 'influenza A'},
#  {'start': 960, 'end': 976, 'text': 'influenza A H1N1'},
#  {'start': 1024, 'end': 1040, 'text': 'influenza A H1N1'},
#  {'start': 594, 'end': 606, 'text': 'A. petiolata'},
#  {'start': 236, 'end': 241, 'text': 'human'},
#  {'start': 463, 'end': 486, 'text': 'human influenza virus A'},
#  {'start': 520, 'end': 547, 'text': 'respiratory syncytial virus'},
#  {'start': 1332, 'end': 1353, 'text': 'human influenza virus'},
#  {'start': 1358, 'end': 1385, 'text': 'respiratory syncytial virus'},
#  {'start': 223, 'end': 258, 'text': 'human immunodeficiency virus type 1'},
#  {'start': 260, 'end': 265, 'text': 'HIV-1'},
#  {'start': 89, 'end': 93, 'text': 'rice'},
#  {'start': 176, 'end': 186, 'text': 'Asian rice'},
#  {'start': 507, 'end': 511, 'text': 'rice'},
#  {'start': 646, 'end': 650, 'text': 'rice'},
#  {'start': 1258, 'end': 1262, 'text': 'rice'},
#  {'start': 1383, 'end': 1405, 'text': 'tropical japonica rice'},
#  {'start': 10, 'end': 20, 'text': 'wSinvictaA'},
#  {'start': 62, 'end': 70, 'text': 'fire ant'},
#  {'start': 960, 'end': 968, 'text': 'fire ant'},
#  {'start': 1361, 'end': 1371, 'text': 'wSinvictaA'},
#  {'start': 1439, 'end': 1447, 'text': 'fire ant'},
#  {'start': 1517, 'end': 1527, 'text': 'wSinvictaA'},
#  {'start': 419, 'end': 429, 'text': 'tawny owls'},
#  {'start': 630, 'end': 640, 'text': 'tawny owls'},
#  {'start': 1714, 'end': 1724, 'text': 'tawny owls'},
#  {'start': 966, 'end': 971, 'text': 'human'},
#  {'start': 69, 'end': 90, 'text': 'yellow fever mosquito'},
#  {'start': 403, 'end': 408, 'text': 'human'},
#  {'start': 70, 'end': 99, 'text': 'Achromobacter xylosoxidans A8'},
#  {'start': 103, 'end': 139, 'text': 'Achromobacter xylosoxidans strain A8'},
#  {'start': 90, 'end': 105, 'text': 'Atlantic salmon'},
#  {'start': 596, 'end': 611, 'text': 'Atlantic salmon'},
#  {'start': 761, 'end': 776, 'text': 'Atlantic salmon'},
#  {'start': 1430, 'end': 1445, 'text': 'Atlantic salmon'},
#  {'start': 2088, 'end': 2103, 'text': 'Atlantic salmon'},
#  {'start': 100, 'end': 119, 'text': 'rice blast pathogen'},
#  {'start': 223, 'end': 227, 'text': 'rice'},
#  {'start': 704, 'end': 714, 'text': 'ATMT0225B6'},
#  {'start': 716, 'end': 730, 'text': 'MoCDC15(T-DNA)'},
#  {'start': 811, 'end': 816, 'text': 'yeast'},
#  {'start': 995, 'end': 1000, 'text': 'yeast'},
#  {'start': 1418, 'end': 1435, 'text': 'wild type MoCDC15'},
#  {'start': 126, 'end': 133, 'text': 'tobacco'},
#  {'start': 95, 'end': 110, 'text': 'corn leafhopper'},
#  {'start': 251, 'end': 255, 'text': 'corn'},
#  {'start': 262, 'end': 269, 'text': 'tobacco'},
#  {'start': 4, 'end': 26, 'text': 'Perigord black truffle'},
#  {'start': 127, 'end': 145, 'text': 'Tuber melanosporum'},
#  {'start': 558, 'end': 581, 'text': 'common brushtail possum'},
#  {'start': 80, 'end': 90, 'text': 'stable fly'},
#  {'start': 272, 'end': 282, 'text': 'stable fly'},
#  {'start': 357, 'end': 367, 'text': 'stable fly'},
#  {'start': 720, 'end': 730, 'text': 'stable fly'},
#  {'start': 545, 'end': 550, 'text': 'swine'},
#  {'start': 943, 'end': 965, 'text': 'S. suis strain 89/1591'},
#  {'start': 28, 'end': 52, 'text': 'Burkholderia rhizoxinica'},
#  {'start': 97, 'end': 121, 'text': 'Burkholderia rhizoxinica'},
#  {'start': 472, 'end': 495, 'text': 'B. rhizoxinica HKI 0454'},
#  {'start': 50, 'end': 62, 'text': 'dengue virus'},
#  {'start': 92, 'end': 106, 'text': 'dengue viruses'},
#  {'start': 395, 'end': 401, 'text': 'Dengue'},
#  {'start': 451, 'end': 457, 'text': 'dengue'},
#  {'start': 545, 'end': 551, 'text': 'dengue'},
#  {'start': 855, 'end': 867, 'text': 'dengue virus'},
#  {'start': 1214, 'end': 1220, 'text': 'dengue'},
#  {'start': 1405, 'end': 1411, 'text': 'dengue'},
#  {'start': 1661, 'end': 1667, 'text': 'dengue'},
#  {'start': 1691, 'end': 1697, 'text': 'dengue'},
#  {'start': 192, 'end': 196, 'text': 'rice'},
#  {'start': 1586, 'end': 1591, 'text': 'human'},
#  {'start': 84, 'end': 101, 'text': 'coxsackievirus B3'},
#  {'start': 633, 'end': 650, 'text': 'coxsackievirus B3'},
#  {'start': 652, 'end': 656, 'text': 'CVB3'},
#  {'start': 707, 'end': 713, 'text': 'humans'},
#  {'start': 907, 'end': 911, 'text': 'CVB3'},
#  {'start': 1349, 'end': 1353, 'text': 'CVB3'},
#  {'start': 538, 'end': 552, 'text': 'European beech'},
#  {'start': 582, 'end': 595, 'text': 'Norway spruce'},
#  {'start': 46, 'end': 83, 'text': 'Campylobacter fetus subsp. venerealis'},
#  {'start': 215, 'end': 234, 'text': 'Campylobacter fetus'},
#  {'start': 378, 'end': 386, 'text': 'C. fetus'},
#  {'start': 577, 'end': 603, 'text': 'C. fetus subsp. venerealis'},
#  {'start': 700, 'end': 708, 'text': 'C. fetus'},
#  {'start': 1040, 'end': 1048, 'text': 'C. fetus'},
#  {'start': 1155, 'end': 1160, 'text': 'human'},
#  {'start': 1474, 'end': 1482, 'text': 'C. fetus'},
#  {'start': 839, 'end': 846, 'text': 'cabbage'},
#  {'start': 194, 'end': 221, 'text': 'herpes simplex virus type 1'},
#  {'start': 223, 'end': 228, 'text': 'HSV-1'},
#  {'start': 234, 'end': 252, 'text': 'pseudorabies virus'},
#  {'start': 254, 'end': 257, 'text': 'PRV'},
#  {'start': 272, 'end': 294, 'text': 'varicella-zoster virus'},
#  {'start': 296, 'end': 299, 'text': 'VZV'},
#  {'start': 438, 'end': 443, 'text': 'HSV-1'},
#  {'start': 619, 'end': 624, 'text': 'HSV-1'},
#  {'start': 626, 'end': 629, 'text': 'VZV'},
#  {'start': 635, 'end': 638, 'text': 'PRV'},
#  {'start': 735, 'end': 738, 'text': 'VZV'},
#  {'start': 876, 'end': 881, 'text': 'HSV-1'},
#  {'start': 886, 'end': 889, 'text': 'PRV'},
#  {'start': 930, 'end': 933, 'text': 'VZV'},
#  {'start': 986, 'end': 989, 'text': 'VZV'},
#  {'start': 1186, 'end': 1189, 'text': 'VZV'},
#  {'start': 1229, 'end': 1232, 'text': 'VZV'},
#  {'start': 1349, 'end': 1352, 'text': 'VZV'},
#  {'start': 1552, 'end': 1557, 'text': 'HSV-1'},
#  {'start': 1561, 'end': 1564, 'text': 'PRV'},
#  {'start': 91, 'end': 99, 'text': 'silkmoth'},
#  {'start': 654, 'end': 680, 'text': 'P. aeruginosa strain PA103'},
#  {'start': 1839, 'end': 1844, 'text': 'mouse'},
#  {'start': 46, 'end': 85, 'text': "Kaposi's sarcoma-associated herpesvirus"},
#  {'start': 89, 'end': 128, 'text': "Kaposi's sarcoma-associated herpesvirus"},
#  {'start': 130, 'end': 134, 'text': 'KSHV'},
#  {'start': 164, 'end': 169, 'text': 'human'},
#  {'start': 306, 'end': 310, 'text': 'KSHV'},
#  {'start': 869, 'end': 873, 'text': 'KSHV'},
#  {'start': 949, 'end': 953, 'text': 'KSHV'},
#  {'start': 993, 'end': 997, 'text': 'KSHV'},
#  {'start': 1009, 'end': 1014, 'text': 'human'},
#  {'start': 1053, 'end': 1057, 'text': 'KSHV'},
#  {'start': 1312, 'end': 1316, 'text': 'KSHV'},
#  {'start': 208, 'end': 215, 'text': 'M2T2B15'},
#  {'start': 609, 'end': 616, 'text': 'M2T2B15'},
#  {'start': 1105, 'end': 1112, 'text': 'M2T2B15'},
#  {'start': 1227, 'end': 1234, 'text': 'M2T2B15'},
#  {'start': 1367, 'end': 1374, 'text': 'M2T2B15'}]

# %% [markdown]
# #### Eval on COPIOUS GSC

# %%
PATH_TO_COPIOUS_GT = '../corpora/COPIOUS_GSC_brat/copious_clean/test'
PATH_TO_COPIOUS_PRED = "./output/TAXONFINDER/COPIOUS_pred"

# %%
response = run_taxonfinder(PATH_TO_COPIOUS_GT, PATH_TO_COPIOUS_PRED)
parse_taxonfinder(response, PATH_TO_COPIOUS_PRED)

# %%
get_precision_recall_f1_single_corpus(PATH_TO_COPIOUS_PRED, PATH_TO_COPIOUS_GT, criterion=exact)
# Out:
# $48.63$ & $29.51$ & $36.73$
#        precision    recall  f1-score
# Taxon   0.486268  0.295098  0.367297

# %%
get_precision_recall_f1_single_corpus(PATH_TO_COPIOUS_PRED, PATH_TO_COPIOUS_GT, criterion=approximate)
# Out:
# $48.95$ & $29.76$ & $37.02$
#        precision    recall  f1-score
# Taxon   0.489499  0.297642  0.370189

# %%
FN, FP, TP = get_FN_FP_TP_single_corpus(PATH_TO_COPIOUS_PRED, PATH_TO_COPIOUS_GT, criterion=exact)
FN
# Out:
# [{'start': 0, 'end': 8, 'text': 'MAI RANG'},
#  {'start': 366, 'end': 374, 'text': 'Mai Teng'},
#  {'start': 506, 'end': 510, 'text': 'Yang'},
#  {'start': 640, 'end': 648, 'text': 'Mai Rang'},
#  {'start': 779, 'end': 787, 'text': 'MAI RANG'},
#  {'start': 789, 'end': 807, 'text': 'Pentacme Siamensis'},
#  {'start': 826, 'end': 840, 'text': 'Dipterocarpeae'},
#  {'start': 948, 'end': 956, 'text': 'Mai Teng'},
#  {'start': 21, 'end': 47, 'text': 'H. polyalthoides Symington'},
#  {'start': 211, 'end': 232, 'text': 'H. resinosa Symington'},
#  {'start': 590, 'end': 611, 'text': 'Shorea acuminata Dyer'},
#  {'start': 916, 'end': 935, 'text': 'S. bracteolata Dyer'},
#  {'start': 1184, 'end': 1205, 'text': 'S. exelliptica Meijer'},
#  {'start': 1445, 'end': 1465, 'text': 'S. ? elliptica Burck'},
#  {'start': 1499, 'end': 1522, 'text': 'S. foxworthii Symington'},
#  {'start': 2009, 'end': 2014, 'text': 'balau'},
#  {'start': 2073, 'end': 2097, 'text': 'S. lepidota (Korth.) Bl.'},
#  {'start': 2282, 'end': 2299, 'text': 'S. leprosula Miq.'},
#  {'start': 2404, 'end': 2426, 'text': 'S. ovalis (Korth.) Bl.'},
#  {'start': 2945, 'end': 2965, 'text': 'Mesua kochummeniatia'},
#  {'start': 3023, 'end': 3042, 'text': 'S. palembanica Miq.'},
#  {'start': 3323, 'end': 3333, 'text': 'sengkawang'},
#  {'start': 3337, 'end': 3347, 'text': 'tengkawang'},
#  {'start': 3446, 'end': 3457, 'text': '5. lepidota'},
#  {'start': 2324, 'end': 2333, 'text': 'Porcupine'},
#  {'start': 2700, 'end': 2717, 'text': 'Sagrina bifrons H'},
#  {'start': 691, 'end': 700, 'text': 'Albatross'},
#  {'start': 2681, 'end': 2690, 'text': 'Lagenidse'},
#  {'start': 133, 'end': 162, 'text': 'Symplioricarpos rotundifolius'},
#  {'start': 164, 'end': 190, 'text': 'Symphoricarpos paucifiorus'},
#  {'start': 196, 'end': 216, 'text': 'Symphoricarpos alhus'},
#  {'start': 270, 'end': 304, 'text': 'Symphoricarpos rotundifolius, Gray'},
#  {'start': 306, 'end': 325, 'text': 'Soundleaf snowberry'},
#  {'start': 327, 'end': 344, 'text': 'S. glaucus Eastw.'},
#  {'start': 346, 'end': 367, 'text': 'S. parvlfolius Bastw.'},
#  {'start': 369, 'end': 390, 'text': '8. vaccinioides Rydb.'},
#  {'start': 393, 'end': 412, 'text': 'S. tetonensis Nels.'},
#  {'start': 589, 'end': 595, 'text': 'thrush'},
#  {'start': 597, 'end': 613, 'text': 'California quail'},
#  {'start': 629, 'end': 638, 'text': 'Chipmunli'},
#  {'start': 640, 'end': 660, 'text': 'California mule deer'},
#  {'start': 675, 'end': 680, 'text': 'sheep'},
#  {'start': 685, 'end': 689, 'text': 'goat'},
#  {'start': 733, 'end': 758, 'text': 'SymphmHcarpos orbiculatus'},
#  {'start': 821, 'end': 851, 'text': 'Symphoricarpos utahensis Rydb.'},
#  {'start': 852, 'end': 866, 'text': 'Utah snowberry'},
#  {'start': 979, 'end': 1008, 'text': 'Symphoricarpos rotundifoliiis'},
#  {'start': 1039, 'end': 1065, 'text': 'Symphoricarpos orhiculatus'},
#  {'start': 1067, 'end': 1098, 'text': "Symplocos tinctoria (L.) L'Her."},
#  {'start': 1099, 'end': 1108, 'text': 'Sweetleaf'},
#  {'start': 1110, 'end': 1128, 'text': 'Hopea tinctoria L.'},
#  {'start': 1451, 'end': 1457, 'text': 'Phoebe'},
#  {'start': 1471, 'end': 1477, 'text': 'cattle'},
#  {'start': 1479, 'end': 1505, 'text': 'Talinopsis frntescens Gray'},
#  {'start': 1587, 'end': 1602, 'text': 'Persea horbonia'},
#  {'start': 1624, 'end': 1639, 'text': 'Persea hiimilis'},
#  {'start': 1663, 'end': 1680, 'text': 'Persea. pulescens'},
#  {'start': 1682, 'end': 1701, 'text': "Tamarix g'allica L."},
#  {'start': 1702, 'end': 1710, 'text': 'Tamarisk'},
#  {'start': 2119, 'end': 2132, 'text': 'Taxodinm spp.'},
#  {'start': 2133, 'end': 2144, 'text': 'Baldcypress'},
#  {'start': 2233, 'end': 2244, 'text': 'wild turkey'},
#  {'start': 2295, 'end': 2313, 'text': 'Texas fox squirrel'},
#  {'start': 2315, 'end': 2341, 'text': 'Taxodinm ascendens Brongn.'},
#  {'start': 2342, 'end': 2353, 'text': 'Pondcypress'},
#  {'start': 2355, 'end': 2383, 'text': 'T. imbricarium (Nutt.) Harp.'},
#  {'start': 2476, 'end': 2494, 'text': 'Little brown crane'},
#  {'start': 1301, 'end': 1315, 'text': 'Dipterocarpeae'},
#  {'start': 1972, 'end': 1988, 'text': 'daun batik angin'},
#  {'start': 2459, 'end': 2468, 'text': 'squirrels'},
#  {'start': 2622, 'end': 2631, 'text': 'crocodile'},
#  {'start': 2702, 'end': 2713, 'text': 'buaya katak'},
#  {'start': 2839, 'end': 2853, 'text': 'Gunong Tundong'},
#  {'start': 485, 'end': 505, 'text': 'C. nigricans, Brooke'},
#  {'start': 388, 'end': 403, 'text': 'Philippine deer'},
#  {'start': 1293, 'end': 1308, 'text': 'Philippine deer'},
#  {'start': 85, 'end': 89, 'text': 'bird'},
#  {'start': 155, 'end': 175, 'text': 'Bucco niger, Indorni'},
#  {'start': 284, 'end': 311, 'text': 'Black-throated Barbet, Gen.'},
#  {'start': 362, 'end': 377, 'text': 'Common Grosbeak'},
#  {'start': 1459, 'end': 1479, 'text': 'Bucco niger, Indorni'},
#  {'start': 130, 'end': 153, 'text': 'BLACK-THROATED BARBICAN'},
#  {'start': 1550, 'end': 1568, 'text': 'Red-fronted Barbet'},
#  {'start': 75, 'end': 100, 'text': 'Shorea multiflora (Burck)'},
#  {'start': 602, 'end': 613, 'text': '5. curtisii'},
#  {'start': 2354, 'end': 2383, 'text': 'Plectropomus truncatus Fowler'},
#  {'start': 261, 'end': 272, 'text': 'Ohagurohata'},
#  {'start': 311, 'end': 340, 'text': 'Cephalopholis argus Schneider'},
#  {'start': 353, 'end': 360, 'text': 'kaleaej'},
#  {'start': 2396, 'end': 2402, 'text': 'akajin'},
#  {'start': 2404, 'end': 2418, 'text': 'kurobanlakajln'},
#  {'start': 2309, 'end': 2315, 'text': 'Akajin'},
#  {'start': 42, 'end': 78, 'text': 'Archamia bleekeri (Glinther) Masangm'},
#  {'start': 1031, 'end': 1057, 'text': 'Ambassis urotsenia Bleeker'},
#  {'start': 1779,
#   'end': 1823,
#   'text': 'Pempheris vanicolensis Cuvier & Valenciennes'},
#  {'start': 2130,
#   'end': 2173,
#   'text': 'Pempherit vanicduntis Cuvier & Valenciennes'},
#  {'start': 2227, 'end': 2237, 'text': 'SERRANID-F'},
#  {'start': 2244, 'end': 2267, 'text': 'Epinephelus merra Bloch'},
#  {'start': 2428, 'end': 2457, 'text': 'Epinephelus tauvina (Forskal)'},
#  {'start': 2509, 'end': 2530, 'text': 'Perea tauvina Forskal'},
#  {'start': 2564, 'end': 2594, 'text': 'Epinephelus tauvina, Boulenger'},
#  {'start': 2612, 'end': 2643, 'text': 'Epinephelus fasciatus (Forskal)'},
#  {'start': 2701, 'end': 2723, 'text': 'Perea faieiata Forskal'},
#  {'start': 2756, 'end': 2788, 'text': 'Epinephelus fasciatus, Boulenger'},
#  {'start': 1409, 'end': 1440, 'text': 'Ambassis lung-i (Jordan & Seale'},
#  {'start': 525, 'end': 552, 'text': 'Chimarrhornis bicolor Grant'},
#  {'start': 834, 'end': 858, 'text': 'Megalurus ruficeps Tweed'},
#  {'start': 1648, 'end': 1667, 'text': 'LOLE PHILIPPINENSIS'},
#  {'start': 3, 'end': 30, 'text': 'Hyloterpe albiventris Grant'},
#  {'start': 1006, 'end': 1034, 'text': 'ZOSTERORNIS whiteheadi Grant'},
#  {'start': 1226, 'end': 1258, 'text': 'PSEUDOTHARRHALEUS CAUDATUS Grant'},
#  {'start': 1276, 'end': 1283, 'text': 'Lepanto'},
#  {'start': 1695, 'end': 1702, 'text': 'Lu bang'},
#  {'start': 1748, 'end': 1753, 'text': 'Verde'},
#  {'start': 1863, 'end': 1879, 'text': 'lole mindorensis'},
#  {'start': 1758, 'end': 1786, 'text': 'Cerithium macrotoma, Islands'},
#  {'start': 1912, 'end': 1939, 'text': 'Oolina pupiformis, A. Adams'},
#  {'start': 2000, 'end': 2029, 'text': 'Ceiithium pupeeforme A. Adams'},
#  {'start': 2128, 'end': 2152, 'text': 'Colina costata, A. Adams'},
#  {'start': 2176, 'end': 2205, 'text': 'Cerithium costiferum, Sowerby'},
#  {'start': 2286, 'end': 2310, 'text': 'Colina pygmsea, H. Adams'},
#  {'start': 2580, 'end': 2590, 'text': 'O. pygmcea'},
#  {'start': 2736, 'end': 2744, 'text': '0. pygmy'},
#  {'start': 1148, 'end': 1165, 'text': 'Philippine bamboo'},
#  {'start': 826, 'end': 844, 'text': 'thin-walled bamboo'},
#  {'start': 1032, 'end': 1036, 'text': 'Buho'},
#  {'start': 1442,
#   'end': 1480,
#   'text': 'SCHIZOSTACHYUM TEXTORIUM (Blanco) Merr'},
#  {'start': 1482, 'end': 1489, 'text': 'Kalbang'},
#  {'start': 1504, 'end': 1511, 'text': 'kalbang'},
#  {'start': 2373, 'end': 2377, 'text': 'paua'},
#  {'start': 2393, 'end': 2398, 'text': 'puser'},
#  {'start': 545, 'end': 570, 'text': 'Indo-pacific Endodontidae'},
#  {'start': 137, 'end': 154, 'text': 'PHILIPPINE SNAILS'},
#  {'start': 1381, 'end': 1392, 'text': 'endodontids'},
#  {'start': 2202, 'end': 2223, 'text': 'Brucea sumatrana Roxb'},
#  {'start': 2158, 'end': 2174, 'text': 'amarissimus Lour'},
#  {'start': 2116, 'end': 2140, 'text': 'BRUCEA AMARISSIMA (Lour)'},
#  {'start': 2083, 'end': 2095, 'text': 'SIMARUBACEAE'},
#  {'start': 1521, 'end': 1547, 'text': 'CROTALARIA ORIXENSIS Willd'},
#  {'start': 1501, 'end': 1520, 'text': 'CROTALARIA Linnaeus'},
#  {'start': 740, 'end': 769, 'text': 'Hydnocarpus beccariana Sleum.'},
#  {'start': 2168, 'end': 2174, 'text': 'Borneo'},
#  {'start': 2176, 'end': 2183, 'text': 'Sarawak'},
#  {'start': 2185, 'end': 2192, 'text': 'Kuching'},
#  {'start': 2211, 'end': 2240, 'text': 'Hydnocarpus borneensis Sleum.'},
#  {'start': 4208, 'end': 4216, 'text': 'madansat'},
#  {'start': 4218, 'end': 4224, 'text': 'Kwijau'},
#  {'start': 4226, 'end': 4238, 'text': 'pasir-pasir,'},
#  {'start': 4239, 'end': 4252, 'text': 'nangka-nangka'},
#  {'start': 4257, 'end': 4265, 'text': 'empupuak'},
#  {'start': 4267, 'end': 4272, 'text': 'Dusun'},
#  {'start': 4279,
#   'end': 4317,
#   'text': 'Hydnocarpus filipes Symington & Sleum.'},
#  {'start': 5640, 'end': 5648, 'text': 'Setumpol'},
#  {'start': 5657, 'end': 5683, 'text': 'Hydnocarpus castanea Hook.'},
#  {'start': 3, 'end': 13, 'text': 'MAI TAKIEN'},
#  {'start': 28, 'end': 41, 'text': 'Hopea Odorata'},
#  {'start': 77, 'end': 91, 'text': 'Dipterocarpeae'},
#  {'start': 93, 'end': 103, 'text': 'Mai Takien'},
#  {'start': 69, 'end': 78, 'text': 'Tipnlidae'},
#  {'start': 80, 'end': 107, 'text': 'Dicranomyia saltans Dolesch'},
#  {'start': 1830, 'end': 1840, 'text': 'L. Semperi'},
#  {'start': 813, 'end': 830, 'text': 'Liihnotes Semperi'},
#  {'start': 1117, 'end': 1138, 'text': 'Sterculia urens, Roxb'},
#  {'start': 1165, 'end': 1196, 'text': 'Cavallium urens, Schott. & Endl'},
#  {'start': 1659, 'end': 1681, 'text': 'Senegambian gum acacia'},
#  {'start': 1203, 'end': 1216, 'text': 'Yvijg-banilad'},
#  {'start': 5, 'end': 30, 'text': 'DIPTEROCARPACEAE (Ashton)'},
#  {'start': 1114, 'end': 1130, 'text': 'Meranti kerangas'},
#  {'start': 1142, 'end': 1159, 'text': 'seraya daun tajam'},
#  {'start': 1175, 'end': 1203, 'text': 'Shorea ovata DYER ex BRANDIS'},
#  {'start': 1525, 'end': 1555, 'text': 'S. parvifolia (non DYER) KING.'},
#  {'start': 1643, 'end': 1659, 'text': 'S. plagata FOXW.'},
#  {'start': 1718, 'end': 1744, 'text': 'S. agsaboensis W.L. STERN.'},
#  {'start': 4243, 'end': 4269, 'text': 'Meranti sarang punai bukit'},
#  {'start': 4280, 'end': 4290, 'text': 'mandirawan'},
#  {'start': 4302, 'end': 4320, 'text': 'seraya punai bukit'},
#  {'start': 5027, 'end': 5039, 'text': 'Brachypterae'},
#  {'start': 5776, 'end': 5795, 'text': 'Shorea rubra ASHTON'},
#  {'start': 4, 'end': 29, 'text': 'Polygala acicularis, Oliv'},
#  {'start': 284, 'end': 296, 'text': 'Hypebicaceae'},
#  {'start': 298, 'end': 332, 'text': 'Haronga paniculata, Lodd. ex Steud'},
#  {'start': 355, 'end': 380, 'text': 'Arungana paniculata, Pers'},
#  {'start': 405, 'end': 437, 'text': 'Haronga madugascariensis, Choisy'},
#  {'start': 875, 'end': 891, 'text': 'DiPTEROCARPACEAE'},
#  {'start': 894, 'end': 918, 'text': 'Monotes caloneurus, Gilg'},
#  {'start': 1070, 'end': 1089, 'text': 'Sida linifolia, Cav'},
#  {'start': 1418, 'end': 1436, 'text': 'Sida spinosa, Linn'},
#  {'start': 1487, 'end': 1508, 'text': 'Sida cordifolia, Linn'},
#  {'start': 1596, 'end': 1614, 'text': 'Urena lobata, Linn'},
#  {'start': 456, 'end': 481, 'text': 'Lagerstroemia flosreginae'},
#  {'start': 639, 'end': 660, 'text': 'Athrocephalus cadamba'},
#  {'start': 701, 'end': 715, 'text': 'Bridela retusa'},
#  {'start': 803, 'end': 815, 'text': 'Garcinia sp.'},
#  {'start': 858, 'end': 875, 'text': 'Phoebe cooperiana'},
#  {'start': 885, 'end': 900, 'text': 'P. goalparansis'},
#  {'start': 1043, 'end': 1058, 'text': 'A. integriflora'},
#  {'start': 44, 'end': 58, 'text': 'T. anguina, L.'},
#  {'start': 60, 'end': 76, 'text': 'T. amara, Blanco'},
#  {'start': 91, 'end': 101, 'text': 'Salagsalag'},
#  {'start': 166, 'end': 173, 'text': 'Tabobog'},
#  {'start': 103, 'end': 110, 'text': 'Pakupis'},
#  {'start': 112, 'end': 123, 'text': 'Salimpolcot'},
#  {'start': 125, 'end': 134, 'text': 'Kukubitan'},
#  {'start': 136, 'end': 145, 'text': 'Halajiala'},
#  {'start': 147, 'end': 157, 'text': 'Buyokbuyok'},
#  {'start': 175, 'end': 184, 'text': 'Kukubitan'},
#  {'start': 186, 'end': 195, 'text': 'Pukopukot'},
#  {'start': 197, 'end': 204, 'text': 'Kuranda'},
#  {'start': 216, 'end': 232, 'text': 'T. cucumerina, L'},
#  {'start': 478, 'end': 487, 'text': 'P. Blanco'},
#  {'start': 1382, 'end': 1389, 'text': 'Swertia'},
#  {'start': 1391, 'end': 1397, 'text': 'errata'},
#  {'start': 1608, 'end': 1617, 'text': 'coriander'},
#  {'start': 1621, 'end': 1626, 'text': 'cumin'},
#  {'start': 575, 'end': 590, 'text': 'P. lohata Benth'},
#  {'start': 695, 'end': 729, 'text': 'Wallaceodeiidrou celebica Koorders'},
#  {'start': 1391, 'end': 1419, 'text': 'Albizzia julibrissin Durazz.'},
#  {'start': 1494, 'end': 1516, 'text': 'Albizzia procera Teysm'},
#  {'start': 136, 'end': 165, 'text': 'Pitliecolobium montanum Benth'},
#  {'start': 229, 'end': 254, 'text': 'Pithecolobium Saman Benth'},
#  {'start': 316, 'end': 345, 'text': 'Pithecolobium subacutum Benth'},
#  {'start': 547, 'end': 565, 'text': 'Pitliecolobium sp.'},
#  {'start': 667, 'end': 691, 'text': 'Wallaceodendron Koorders'},
#  {'start': 1371, 'end': 1386, 'text': 'Albizzia Durazz'},
#  {'start': 842, 'end': 872, 'text': 'Plectropomus maculatus (Bloch)'},
#  {'start': 1044, 'end': 1077, 'text': 'PLECTROPOMUS LEOPARDUS (Lacepede)'},
#  {'start': 1167, 'end': 1198, 'text': 'Plectropoma leopard inum Cuvier'},
#  {'start': 1396, 'end': 1402, 'text': 'Karoli'},
#  {'start': 1078, 'end': 1108, 'text': 'Holocentrus leopardus Lacepede'},
#  {'start': 1464,
#   'end': 1503,
#   'text': 'Plectropoma leopardus Richardson, Ichth'},
#  {'start': 24, 'end': 41, 'text': 'THYSANOLAENA Nees'},
#  {'start': 42, 'end': 78, 'text': 'THYSANOLAENA MAXIMA (Roxb) O. Kuntze'},
#  {'start': 200, 'end': 220, 'text': 'Agrostis maxima Roxb'},
#  {'start': 245, 'end': 271, 'text': 'Thysanolaena agrostis Nees'},
#  {'start': 316, 'end': 342, 'text': 'Thysanolaena acarifera Arn'},
#  {'start': 753, 'end': 760, 'text': 'Bugubui'},
#  {'start': 770, 'end': 776, 'text': 'buybui'},
#  {'start': 784, 'end': 790, 'text': 'eagadu'},
#  {'start': 798, 'end': 803, 'text': 'gatbo'},
#  {'start': 812, 'end': 816, 'text': 'lasa'},
#  {'start': 824, 'end': 831, 'text': 'tagadeu'},
#  {'start': 840, 'end': 846, 'text': 'tagisa'},
#  {'start': 854, 'end': 859, 'text': 'tambu'},
#  {'start': 867, 'end': 877, 'text': 'talankaran'},
#  {'start': 888, 'end': 905, 'text': 'DIGITARIA Scopoli'},
#  {'start': 906, 'end': 930, 'text': 'DIGITARIA CHINENSIS Nees'},
#  {'start': 977, 'end': 1000, 'text': 'Paspalum ftlicidme Nees'},
#  {'start': 1043, 'end': 1068, 'text': 'Digitaria violascens Merr'},
#  {'start': 1434, 'end': 1438, 'text': 'Timi'},
#  {'start': 1446, 'end': 1450, 'text': 'tumi'},
#  {'start': 1458, 'end': 1467, 'text': 'ualisibis'},
#  {'start': 1474, 'end': 1500, 'text': 'DIGITARIA CORYMBOSA (Roxb)'},
#  {'start': 1512, 'end': 1536, 'text': 'Panicum co-rymbosum Roxb'},
#  {'start': 1596, 'end': 1621, 'text': 'Panicum microbachne Presl'},
#  {'start': 1673, 'end': 1700, 'text': 'Digitaria consanguinea Merr'},
#  {'start': 1791, 'end': 1801, 'text': 'Blancoanae'},
#  {'start': 1826, 'end': 1850, 'text': 'Panicum sanguinale Rolfe'},
#  {'start': 1931, 'end': 1954, 'text': 'Digitaria lanosa Llanos'},
#  {'start': 2106,
#   'end': 2146,
#   'text': 'Panicum pruriens Trin. var. glabrum Nees'},
#  {'start': 2343, 'end': 2353, 'text': 'Blancoanae'},
#  {'start': 2521, 'end': 2527, 'text': 'Banana'},
#  {'start': 2535, 'end': 2542, 'text': 'bacilli'},
#  {'start': 2553, 'end': 2562, 'text': 'balisibis'},
#  {'start': 2570, 'end': 2574, 'text': 'baud'},
#  {'start': 126, 'end': 135, 'text': 'GUENTHERI'},
#  {'start': 1048, 'end': 1070, 'text': 'Philippine Platymantis'},
#  {'start': 1176, 'end': 1183, 'text': 'hazelae'},
#  {'start': 1262, 'end': 1269, 'text': 'hazelae'},
#  {'start': 707, 'end': 716, 'text': 'guentheri'},
#  {'start': 726, 'end': 748, 'text': 'Philippine Platymantis'},
#  {'start': 839, 'end': 848, 'text': 'guentheri'},
#  {'start': 851, 'end': 860, 'text': 'P. rabori'},
#  {'start': 14, 'end': 39, 'text': 'USSA CHRYSOTRICHOS Heude.'},
#  {'start': 46, 'end': 75, 'text': 'Ussa chrysotrichos Heude, Mem'},
#  {'start': 164, 'end': 183, 'text': 'Ussa cinereus Heude'},
#  {'start': 191, 'end': 215, 'text': 'Ussa cinereus Heude, Mem'},
#  {'start': 287, 'end': 307, 'text': 'Ussa corteanus Heude'},
#  {'start': 315, 'end': 340, 'text': 'Ussa corteanus Heude, Mem'},
#  {'start': 416, 'end': 439, 'text': 'Ussa crassicornis Heude'},
#  {'start': 447, 'end': 475, 'text': 'Ussa crassicornis Heude, Mem'},
#  {'start': 539, 'end': 564, 'text': 'Ussa dailliardianus Heude'},
#  {'start': 572, 'end': 602, 'text': 'Ussa dailliardianus Heude, Mem'},
#  {'start': 688, 'end': 714, 'text': 'Melanaxis () elegans Heude'},
#  {'start': 722, 'end': 754, 'text': 'Melanaxis () elegans, Heude, Mem'},
#  {'start': 832, 'end': 852, 'text': 'Ussa elorzanus Heude'},
#  {'start': 860, 'end': 885, 'text': 'Ussa elorzanus Heude, Mem'},
#  {'start': 967, 'end': 988, 'text': 'Ussa francianus Heude'},
#  {'start': 996, 'end': 1022, 'text': 'Ussa francianus Heude, Mem'},
#  {'start': 1096, 'end': 1116, 'text': 'Ussa garcianus Heude'},
#  {'start': 1124, 'end': 1149, 'text': 'Ussa garcianus Heude, Mem'},
#  {'start': 1226, 'end': 1247, 'text': 'Ussa gonzalinus Heude'},
#  {'start': 1255, 'end': 1281, 'text': 'Ussa gonzalinus Heude, Mem'},
#  {'start': 1368, 'end': 1390, 'text': 'Ussa gorrichanus Heude'},
#  {'start': 1398, 'end': 1425, 'text': 'Ussa gorrichanus Heude, Mem'},
#  {'start': 163, 'end': 173, 'text': 'Sago palms'},
#  {'start': 423, 'end': 434, 'text': 'Phanerogams'},
#  {'start': 466, 'end': 476, 'text': 'Cryptogams'},
#  {'start': 573, 'end': 592, 'text': 'Cycas Rumphii, Miq.'},
#  {'start': 622, 'end': 642, 'text': 'Cycas medica, R. Br.'},
#  {'start': 678, 'end': 699, 'text': 'Cycas revoluta, Thumb'},
#  {'start': 736, 'end': 758, 'text': 'Cycas sia-mensis, Miq.'},
#  {'start': 1047, 'end': 1079, 'text': 'DIPTEROCARPUS TUBERCULATUS, ROXB'},
#  {'start': 1564, 'end': 1567, 'text': 'Eng'},
#  {'start': 63, 'end': 81, 'text': 'PHILIPPINE TURTLES'},
#  {'start': 278, 'end': 297, 'text': 'terrestrial turtles'},
#  {'start': 1006, 'end': 1013, 'text': 'turtles'},
#  {'start': 1253, 'end': 1265, 'text': 'land turtles'},
#  {'start': 1496, 'end': 1502, 'text': 'turtle'},
#  {'start': 1602, 'end': 1608, 'text': 'turtle'},
#  {'start': 35, 'end': 55, 'text': 'Poisonous Sea Snakes'},
#  {'start': 73, 'end': 83, 'text': 'sea snakes'},
#  {'start': 427, 'end': 437, 'text': 'sea snakes'},
#  {'start': 544, 'end': 554, 'text': 'sea snakes'},
#  {'start': 563, 'end': 584, 'text': 'elephant-trunk snakes'},
#  {'start': 607, 'end': 619, 'text': 'river snakes'},
#  {'start': 620, 'end': 629, 'text': 'E7ihydris'},
#  {'start': 701, 'end': 722, 'text': 'elephant-trunk snakes'},
#  {'start': 769, 'end': 779, 'text': 'sea snakes'},
#  {'start': 794, 'end': 804, 'text': 'sea snakes'},
#  {'start': 841, 'end': 862, 'text': 'elephant-trunk snakes'},
#  {'start': 898, 'end': 902, 'text': 'Eels'},
#  {'start': 932, 'end': 942, 'text': 'sea snakes'},
#  {'start': 956, 'end': 965, 'text': 'sea snake'},
#  {'start': 1036, 'end': 1046, 'text': 'Sea snakes'},
#  {'start': 1212, 'end': 1229, 'text': 'pelagic sea snake'},
#  {'start': 1231, 'end': 1239, 'text': 'Pejamj-s'},
#  {'start': 1407, 'end': 1419, 'text': 'Xo sea snake'},
#  {'start': 1459, 'end': 1476, 'text': 'pelagic sea snake'},
#  {'start': 1774, 'end': 1784, 'text': 'sea snakes'},
#  {'start': 1881, 'end': 1891, 'text': 'sea snakes'},
#  {'start': 2762, 'end': 2772, 'text': 'Sea snakes'},
#  {'start': 2797, 'end': 2801, 'text': 'Eels'},
#  {'start': 2912, 'end': 2922, 'text': 'Sea snakes'},
#  {'start': 3482, 'end': 3492, 'text': 'sea snakes'},
#  {'start': 2856, 'end': 2868, 'text': 'Deraniyagala'},
#  {'start': 191, 'end': 199, 'text': 'Sailfish'},
#  {'start': 244, 'end': 249, 'text': 'Dakar'},
#  {'start': 386, 'end': 403, 'text': 'Atlantic sailfish'},
#  {'start': 513, 'end': 521, 'text': 'sailfish'},
#  {'start': 457, 'end': 465, 'text': 'sailfish'},
#  {'start': 697, 'end': 708, 'text': 'Blue marlin'},
#  {'start': 858, 'end': 870, 'text': 'Black marlin'},
#  {'start': 1061, 'end': 1070, 'text': 'Swordfish'},
#  {'start': 1174, 'end': 1180, 'text': 'marlin'},
#  {'start': 1185, 'end': 1201, 'text': 'sailfish angling'},
#  {'start': 1277, 'end': 1289, 'text': 'Black marlin'},
#  {'start': 1291, 'end': 1305, 'text': 'striped marlin'},
#  {'start': 1307, 'end': 1318, 'text': 'blue marlin'},
#  {'start': 1324, 'end': 1332, 'text': 'sailfish'},
#  {'start': 1371, 'end': 1383, 'text': 'White marlin'},
#  {'start': 1385, 'end': 1404, 'text': 'shortbill spearfish'},
#  {'start': 1410, 'end': 1428, 'text': 'longbill spearfish'},
#  {'start': 1700, 'end': 1712, 'text': 'black marlin'},
#  {'start': 1717, 'end': 1725, 'text': 'sailfish'},
#  {'start': 1761, 'end': 1770, 'text': 'swordfish'},
#  {'start': 1816, 'end': 1828, 'text': 'black marlin'},
#  {'start': 1881, 'end': 1889, 'text': 'sailfish'},
#  {'start': 1993, 'end': 2005, 'text': 'black marlin'},
#  {'start': 2076, 'end': 2088, 'text': 'black marlin'},
#  {'start': 2230, 'end': 2238, 'text': 'sailfish'},
#  {'start': 2472, 'end': 2480, 'text': 'sailfish'},
#  {'start': 2501, 'end': 2509, 'text': 'sailfish'},
#  {'start': 2585, 'end': 2616, 'text': 'Black, blue, and striped marlin'},
#  {'start': 2621, 'end': 2629, 'text': 'sailfish'},
#  {'start': 2761, 'end': 2773, 'text': 'black marlin'},
#  {'start': 2781, 'end': 2800, 'text': 'shortbill spearfish'},
#  {'start': 2805, 'end': 2814, 'text': 'swordfish'},
#  {'start': 2899, 'end': 2908, 'text': 'swordfish'},
#  {'start': 3090, 'end': 3121, 'text': 'black, blue, and striped marlin'},
#  {'start': 3134, 'end': 3143, 'text': 'swordfish'},
#  {'start': 3148, 'end': 3167, 'text': 'shortbill spearfish'},
#  {'start': 3384, 'end': 3394, 'text': 'billfishes'},
#  {'start': 3478, 'end': 3484, 'text': 'marlin'},
#  {'start': 3489, 'end': 3497, 'text': 'sailfish'},
#  {'start': 3739, 'end': 3751, 'text': 'black marlin'},
#  {'start': 3878, 'end': 3890, 'text': 'black marlin'},
#  {'start': 3970, 'end': 3978, 'text': 'sailfish'},
#  {'start': 4167, 'end': 4175, 'text': 'billfish'},
#  {'start': 4239, 'end': 4253, 'text': 'striped marlin'},
#  {'start': 4258, 'end': 4266, 'text': 'sailfish'},
#  {'start': 4584, 'end': 4596, 'text': 'Black marlin'},
#  {'start': 4662, 'end': 4672, 'text': 'Billfishes'},
#  {'start': 4828, 'end': 4838, 'text': 'Billfishes'},
#  {'start': 5007, 'end': 5019, 'text': 'black marlin'},
#  {'start': 5024, 'end': 5032, 'text': 'sailfish'},
#  {'start': 73, 'end': 92, 'text': 'Hopea nervosa, King'},
#  {'start': 1118, 'end': 1138, 'text': 'Hopea Curtisii, King'},
#  {'start': 2626, 'end': 2648, 'text': 'Hopea miceantha, Hook.'},
#  {'start': 964, 'end': 980, 'text': 'coast of Florida'},
#  {'start': 2923, 'end': 2940, 'text': 'Atlantic sailfish'},
#  {'start': 47, 'end': 55, 'text': 'Sailfish'},
#  {'start': 267, 'end': 275, 'text': 'billfish'},
#  {'start': 381, 'end': 389, 'text': 'sailfish'},
#  {'start': 685, 'end': 693, 'text': 'sailfish'},
#  {'start': 809, 'end': 817, 'text': 'sailfish'},
#  {'start': 1025, 'end': 1033, 'text': 'billfish'},
#  {'start': 1108, 'end': 1116, 'text': 'sailfish'},
#  {'start': 1278, 'end': 1286, 'text': 'sailfish'},
#  {'start': 1455, 'end': 1463, 'text': 'sailfish'},
#  {'start': 1625, 'end': 1633, 'text': 'sailfish'},
#  {'start': 1989, 'end': 1997, 'text': 'sailfish'},
#  {'start': 2338, 'end': 2346, 'text': 'Sailfish'},
#  {'start': 2457, 'end': 2465, 'text': 'sailfish'},
#  {'start': 2530, 'end': 2538, 'text': 'sailfish'},
#  {'start': 2649, 'end': 2657, 'text': 'sailfish'},
#  {'start': 1428, 'end': 1449, 'text': 'Cacatua h^maturopygia'},
#  {'start': 1400, 'end': 1409, 'text': 'PSITTACI.'},
#  {'start': 1410, 'end': 1424, 'text': 'PLYCTOLOPHID.E'},
#  {'start': 667, 'end': 681, 'text': 'Dipterocarpeas'},
#  {'start': 999, 'end': 1007, 'text': 'Hagachac'},
#  {'start': 1330, 'end': 1334, 'text': 'SUPA'},
#  {'start': 1337, 'end': 1361, 'text': 'Sindora Wallichii, Benth'},
#  {'start': 1390, 'end': 1394, 'text': 'Supa'},
#  {'start': 1638, 'end': 1642, 'text': 'Ipil'},
#  {'start': 2038, 'end': 2042, 'text': 'Supa'},
#  {'start': 2244, 'end': 2248, 'text': 'Ipil'},
#  {'start': 2254, 'end': 2258, 'text': 'Supa'},
#  {'start': 49, 'end': 59, 'text': 'MILKFISHES'},
#  {'start': 68, 'end': 74, 'text': 'Chanid'},
#  {'start': 89, 'end': 93, 'text': 'five'},
#  {'start': 97, 'end': 105, 'text': 'milkfish'},
#  {'start': 106, 'end': 129, 'text': 'Chanos chanos (Forskal)'},
#  {'start': 138, 'end': 145, 'text': 'baitgos'},
#  {'start': 147, 'end': 154, 'text': 'haiigod'},
#  {'start': 156, 'end': 168, 'text': 'kaivag-hawag'},
#  {'start': 174, 'end': 183, 'text': 'iumulocso'},
#  {'start': 205, 'end': 214, 'text': 'iangellus'},
#  {'start': 734, 'end': 740, 'text': 'bangos'},
#  {'start': 897, 'end': 903, 'text': 'bangos'},
#  {'start': 769, 'end': 775, 'text': 'mullet'},
#  {'start': 873, 'end': 879, 'text': 'bangos'},
#  {'start': 967, 'end': 976, 'text': 'Iumulocso'},
#  {'start': 1093, 'end': 1105, 'text': 'kawag-kaivag'},
#  {'start': 1612, 'end': 1620, 'text': 'biiitgos'},
#  {'start': 1901, 'end': 1907, 'text': 'bangos'},
#  {'start': 2314, 'end': 2320, 'text': 'bangos'},
#  {'start': 318, 'end': 326, 'text': 'Yakahalu'},
#  {'start': 442, 'end': 458, 'text': 'BeraliyaYakahalu'},
#  {'start': 907, 'end': 929, 'text': 'D. congestiflora, Thw.'},
#  {'start': 948, 'end': 954, 'text': 'Tiniya'},
#  {'start': 1751, 'end': 1770, 'text': 'D. cordifolia, Thw.'},
#  {'start': 1788, 'end': 1796, 'text': 'Beraliya'},
#  {'start': 417, 'end': 452, 'text': 'Rhinolophus virgo K. Anderson, 1905'},
#  {'start': 457, 'end': 483, 'text': 'yellow-faced horseshoe bat'},
#  {'start': 1162, 'end': 1173, 'text': 'Common Bats'},
#  {'start': 1174, 'end': 1202, 'text': 'Murina cyclotis Dobson, 1872'},
#  {'start': 1207, 'end': 1233, 'text': 'round-eared tube-nosed bat'},
#  {'start': 1798, 'end': 1815, 'text': 'Javan pipistrelle'},
#  {'start': 24, 'end': 47, 'text': 'Shorea robusta, Gaertn.'},
#  {'start': 78, 'end': 81, 'text': 'Sal'},
#  {'start': 85, 'end': 89, 'text': 'Saul'},
#  {'start': 347, 'end': 371, 'text': 'Shorea Tumbuggaia, Roxb.'},
#  {'start': 780, 'end': 803, 'text': 'Hopea parviflora, Bedd.'},
#  {'start': 809, 'end': 820, 'text': 'Kiral boghi'},
#  {'start': 822, 'end': 826, 'text': 'Bogi'},
#  {'start': 828, 'end': 834, 'text': 'Tirpul'},
#  {'start': 1418, 'end': 1433, 'text': 'Diptero-carpeae'},
#  {'start': 1583, 'end': 1597, 'text': 'Pt. innornatus'},
#  {'start': 1620, 'end': 1649, 'text': 'Funambulus vittatus (Sciurus)'},
#  {'start': 14, 'end': 33, 'text': 'Dugong dugon Muller'},
#  {'start': 41, 'end': 63, 'text': 'Trichecus dugon Muller'},
#  {'start': 1065, 'end': 1069, 'text': 'bats'},
#  {'start': 290, 'end': 319, 'text': 'Nyctinomiis johorensis DOBSON'},
#  {'start': 651, 'end': 681, 'text': 'Chserephon plicatus (Buchanan)'},
#  {'start': 1068, 'end': 1096, 'text': 'Plnelmarfes foina (Erxleben)'},
#  {'start': 1444, 'end': 1471, 'text': 'Martes henricii (Westerman)'},
#  {'start': 14, 'end': 33, 'text': 'Kerivouta whitehead'},
#  {'start': 49, 'end': 90, 'text': 'Kerivoula whiteheadi Thomas, Ann. and Mag'},
#  {'start': 178, 'end': 186, 'text': 'MOLOSSID'},
#  {'start': 194, 'end': 211, 'text': 'CHAEREPHON Dobson'},
#  {'start': 219, 'end': 243, 'text': 'Chaerephon Dobson, Journ'},
#  {'start': 689, 'end': 726, 'text': 'Vespertilio plicatus Buchannan, Trans'},
#  {'start': 753, 'end': 786, 'text': 'Chaerephon plicatus Andersen, Ann'},
#  {'start': 947, 'end': 955, 'text': 'MUSTELID'},
#  {'start': 963, 'end': 975, 'text': 'MARTES Pinel'},
#  {'start': 983, 'end': 1002, 'text': 'Martes Pinel, Actes'},
#  {'start': 1098, 'end': 1105, 'text': 'Martens'},
#  {'start': 1166, 'end': 1178, 'text': 'domestic cat'},
#  {'start': 1479, 'end': 1514, 'text': 'Mustela (Martes) henricii Westerman'},
#  {'start': 294, 'end': 304, 'text': 'gastropods'},
#  {'start': 1146, 'end': 1174, 'text': 'Liotina peron (Kiener, 1839)'},
#  {'start': 1179, 'end': 1211, 'text': 'Dentarene loculosa (Gould, 1859)'},
#  {'start': 2627, 'end': 2648, 'text': 'Turbinidae Rafinesque'},
#  {'start': 2665, 'end': 2694, 'text': 'Liotiinae H. & A. Adams, 1854'},
#  {'start': 2925, 'end': 2933, 'text': 'turbinid'},
#  {'start': 3067, 'end': 3092, 'text': 'Turbinidae (Mclean, 1987)'},
#  {'start': 3100, 'end': 3116, 'text': 'Bathyhotina Habe'},
#  {'start': 3160, 'end': 3188, 'text': 'Liotia armata A. Adams, 1861'},
#  {'start': 3623, 'end': 3638, 'text': 'Liotina Fischer'},
#  {'start': 3527, 'end': 3535, 'text': 'liotiine'},
#  {'start': 3646, 'end': 3663, 'text': 'Dentarene Iredale'},
#  {'start': 3675, 'end': 3694, 'text': 'Austroliotia Cotton'},
#  {'start': 73, 'end': 93, 'text': 'Mollusca  Gastropoda'},
#  {'start': 1334, 'end': 1355, 'text': 'Cypraea bee kit Gasko'},
#  {'start': 2860, 'end': 2883, 'text': 'Cypraea fultoni Sowerby'},
#  {'start': 257, 'end': 264, 'text': 'cowries'},
#  {'start': 467, 'end': 503, 'text': 'Cypraea (Notadusta) martini Schepman'},
#  {'start': 2441, 'end': 2448, 'text': 'Grouper'},
#  {'start': 2559, 'end': 2565, 'text': 'cowrie'},
#  {'start': 2852, 'end': 2858, 'text': 'cowrie'},
#  {'start': 2953, 'end': 2966, 'text': 'Musselcracker'},
#  {'start': 3091, 'end': 3104, 'text': 'Musselcracker'},
#  {'start': 3287, 'end': 3294, 'text': 'Grouper'},
#  {'start': 3466, 'end': 3473, 'text': 'Grouper'},
#  {'start': 3695, 'end': 3710, 'text': 'Mussel-crackers'},
#  {'start': 3803, 'end': 3810, 'text': 'Grouper'},
#  {'start': 9, 'end': 23, 'text': 'DIPTEROCARPEAE'},
#  {'start': 26, 'end': 53, 'text': 'Monotes Var. /3. hypoleucus'},
#  {'start': 2197, 'end': 2201, 'text': 'Sida'},
#  {'start': 2341, 'end': 2350, 'text': 'Gossyjnum'},
#  {'start': 2657, 'end': 2661, 'text': 'Sida'},
#  {'start': 25, 'end': 50, 'text': 'Premna integrifolia Linn.'},
#  {'start': 52, 'end': 71, 'text': 'Vitex negundo Linn.'},
#  {'start': 87, 'end': 115, 'text': 'Anacardium occidentale Linn.'},
#  {'start': 121, 'end': 136, 'text': 'cashew-nut tree'},
#  {'start': 154, 'end': 183, 'text': 'Calophyllum inophyllum. Linn.'},
#  {'start': 202, 'end': 206, 'text': 'Undi'},
#  {'start': 229, 'end': 263, 'text': "convolvulaceous goat'sfoot creeper"},
#  {'start': 264, 'end': 285, 'text': 'Ipomaea biloba Forsk.'},
#  {'start': 288, 'end': 313, 'text': 'Cassytha filiformis Linn.'},
#  {'start': 322, 'end': 331, 'text': 'Laurineae'},
#  {'start': 415, 'end': 422, 'text': 'Ipomsea'},
#  {'start': 1672, 'end': 1677, 'text': 'canes'},
#  {'start': 1679, 'end': 1684, 'text': 'ferns'},
#  {'start': 1708, 'end': 1713, 'text': 'palms'},
#  {'start': 1745, 'end': 1777, 'text': 'Dipterocarpus turbinates Gaertn.'},
#  {'start': 1824, 'end': 1843, 'text': 'Cedrela toona Roxb.'},
#  {'start': 1925, 'end': 1930, 'text': 'ebony'},
#  {'start': 1936, 'end': 1945, 'text': 'Laurineae'},
#  {'start': 1947, 'end': 1954, 'text': 'laurels'},
#  {'start': 1966, 'end': 1970, 'text': 'figs'},
#  {'start': 1975, 'end': 1990, 'text': 'jackfruit-trees'},
#  {'start': 2075, 'end': 2089, 'text': 'Murray a Linn.'},
#  {'start': 2091, 'end': 2106, 'text': 'Glycosmis Corr.'},
#  {'start': 2120, 'end': 2128, 'text': 'cinnamon'},
#  {'start': 2130, 'end': 2143, 'text': 'Litssea Lamk.'},
#  {'start': 2145, 'end': 2162, 'text': 'Actinodaphne Nees'},
#  {'start': 2164, 'end': 2173, 'text': 'Laurineae'},
#  {'start': 2191, 'end': 2206, 'text': 'Psychotria Linn'},
#  {'start': 2229, 'end': 2253, 'text': 'Chasalia curviflora Thw.'},
#  {'start': 2273, 'end': 2278, 'text': 'lxora'},
#  {'start': 2389, 'end': 2396, 'text': 'orchids'},
#  {'start': 2398, 'end': 2403, 'text': 'arums'},
#  {'start': 2405, 'end': 2418, 'text': 'Zinziberaceae'},
#  {'start': 2423, 'end': 2428, 'text': 'ferns'},
#  {'start': 2526, 'end': 2538, 'text': 'Amoora Roxb.'},
#  {'start': 2540, 'end': 2560, 'text': 'Chikrassia tabularis'},
#  {'start': 2591, 'end': 2609, 'text': 'Schleichera Willd.'},
#  {'start': 2614, 'end': 2628, 'text': 'Sapindis Linn.'},
#  {'start': 2656, 'end': 2661, 'text': 'mango'},
#  {'start': 2666, 'end': 2680, 'text': 'Spondias Linn.'},
#  {'start': 2686, 'end': 2694, 'text': 'hog-plum'},
#  {'start': 2696, 'end': 2710, 'text': 'Holigarna Ham.'},
#  {'start': 2732, 'end': 2747, 'text': 'Dalbergia Linn.'},
#  {'start': 2749, 'end': 2763, 'text': 'Bauhinia Linn.'},
#  {'start': 2765, 'end': 2777, 'text': 'Xylia Benth.'},
#  {'start': 2779, 'end': 2794, 'text': 'Albizzia Durazz'},
#  {'start': 2811, 'end': 2838, 'text': 'Tetrameles nudiflora R. Br.'},
#  {'start': 593, 'end': 601, 'text': 'snappers'},
#  {'start': 606, 'end': 614, 'text': 'groupers'},
#  {'start': 664, 'end': 672, 'text': 'snappers'},
#  {'start': 677, 'end': 685, 'text': 'groupers'},
#  {'start': 1446, 'end': 1460, 'text': 'Trinidad guppy'},
#  {'start': 1583, 'end': 1594, 'text': 'Red grouper'},
#  {'start': 2096, 'end': 2103, 'text': 'grouper'},
#  {'start': 2104, 'end': 2111, 'text': 'snapper'},
#  {'start': 2263, 'end': 2285, 'text': 'shallow-water groupers'},
#  {'start': 2513, 'end': 2524, 'text': 'red snapper'},
#  {'start': 2525, 'end': 2545, 'text': 'lutianus campechanus'},
#  {'start': 2623, 'end': 2640, 'text': 'tropical groupers'},
#  {'start': 2645, 'end': 2653, 'text': 'snappers'},
#  {'start': 4681, 'end': 4688, 'text': 'graysby'},
#  {'start': 5346, 'end': 5354, 'text': 'red deer'},
#  {'start': 712, 'end': 740, 'text': 'Xanthoxylum oxyphyllum, Edge'},
#  {'start': 743, 'end': 761, 'text': 'X. violaceum, Wall'},
#  {'start': 763, 'end': 786, 'text': 'Fagara piperita, Blanco'},
#  {'start': 801, 'end': 809, 'text': 'Kayutana'},
#  {'start': 816, 'end': 821, 'text': 'Salay'},
#  {'start': 823, 'end': 830, 'text': 'Saladay'},
#  {'start': 108, 'end': 124, 'text': 'Vatica Wallichii'},
#  {'start': 1623, 'end': 1639, 'text': 'Vatica Wallichii'},
#  {'start': 1687, 'end': 1703, 'text': 'Vatica Ridleyana'},
#  {'start': 2013, 'end': 2028, 'text': 'Vatica Kelsalli'},
#  {'start': 124, 'end': 128, 'text': 'Salu'},
#  {'start': 152, 'end': 156, 'text': 'Saul'},
#  {'start': 370, 'end': 384, 'text': 'Tiliah-gurjeon'},
#  {'start': 0, 'end': 21, 'text': 'STEMONOPORUS GARDNER!'},
#  {'start': 33, 'end': 47, 'text': 'Dipterocarpeae'},
#  {'start': 50, 'end': 68, 'text': 'STEMONOPORUS. Thw.'},
#  {'start': 922, 'end': 950, 'text': 'STEMONOPORUS GARDNERI (Thw.)'},
#  {'start': 730, 'end': 737, 'text': 'camuyao'},
#  {'start': 746, 'end': 754, 'text': 'hagachac'},
#  {'start': 763, 'end': 768, 'text': 'liput'},
#  {'start': 783,
#   'end': 825,
#   'text': 'Dipterocarpus sp. aff. D. turbinato Gaertn'},
#  {'start': 968, 'end': 1003, 'text': 'D. turbinatus var. andamanicus King'},
#  {'start': 1859, 'end': 1866, 'text': 'apitong'},
#  {'start': 1876, 'end': 1887, 'text': 'patsahingin'},
#  {'start': 1899, 'end': 1928, 'text': 'Dipterocarpus trinervis Blume'},
#  {'start': 2748, 'end': 2755, 'text': 'apitong'},
#  {'start': 13, 'end': 27, 'text': 'Euphorbiaceae.'},
#  {'start': 32, 'end': 42, 'text': 'Latrraceae'},
#  {'start': 1665, 'end': 1684, 'text': 'Imperata  Saccharum'},
#  {'start': 2, 'end': 11, 'text': 'Myrtaceae'},
#  {'start': 366, 'end': 377, 'text': 'molave tree'},
#  {'start': 412, 'end': 416, 'text': 'teak'},
#  {'start': 769, 'end': 781, 'text': 'dipterocarps'},
#  {'start': 910, 'end': 922, 'text': 'Benguet pine'},
#  {'start': 923, 'end': 938, 'text': 'P ins insularis'},
#  {'start': 958, 'end': 970, 'text': 'tapulau pine'},
#  {'start': 971, 'end': 983, 'text': 'P merkusii i'},
#  {'start': 1297, 'end': 1310, 'text': 'Benguet pines'},
#  {'start': 1384, 'end': 1396, 'text': 'tapulau pine'},
#  {'start': 1689, 'end': 1707, 'text': 'Phragmites species'},
#  {'start': 1188, 'end': 1210, 'text': 'Leiognatiiu3 fasciatus'},
#  {'start': 1610, 'end': 1638, 'text': 'Leiognathus edentula (Bloch)'},
#  {'start': 2067, 'end': 2091, 'text': 'Frinihi edntula, Gunther'},
#  {'start': 2150, 'end': 2175, 'text': 'Gazza tapeinosoma Bleeker'},
#  {'start': 2408, 'end': 2433, 'text': 'Gazza argenlaria, Gunther'},
#  {'start': 2478, 'end': 2498, 'text': 'Gazza minuta (Bloch)'},
#  {'start': 2734, 'end': 2755, 'text': 'Scomber minutus Bloch'},
#  {'start': 2876,
#   'end': 2918,
#   'text': 'Xystsema punctatum (Cuvier & Valenciennes)'},
#  {'start': 3237, 'end': 3273, 'text': 'Xystsema baconensis Evermann & Seale'},
#  {'start': 896, 'end': 905, 'text': 'Eu-Shorea'},
#  {'start': 1368, 'end': 1379, 'text': 'S. Curtisii'},
#  {'start': 2170, 'end': 2184, 'text': 'S. Maxwelliana'},
#  {'start': 20, 'end': 36, 'text': 'DIPTEEOCARPACEAE'},
#  {'start': 425, 'end': 441, 'text': 'B. utilis, Bedd.'},
#  {'start': 467, 'end': 489, 'text': 'Hopea longifolia, Dyer'},
#  {'start': 520, 'end': 524, 'text': 'Kong'},
#  {'start': 526, 'end': 535, 'text': 'Kara kong'},
#  {'start': 891, 'end': 906, 'text': 'B. erosa, Bedd.'},
#  {'start': 1104, 'end': 1117, 'text': 'VATICA, Linn.'},
#  {'start': 1249, 'end': 1267, 'text': 'Retinodendron King'},
#  {'start': 2299, 'end': 2321, 'text': 'V. Roxburghiana, Blume'},
#  {'start': 2383, 'end': 2401, 'text': 'V. chinensis Linn.'},
#  {'start': 2544, 'end': 2555, 'text': 'Vella payin'},
#  {'start': 3098, 'end': 3120, 'text': 'V. lanceaefolia, Blume'},
#  {'start': 3149, 'end': 3155, 'text': 'Morhal'},
#  {'start': 3157, 'end': 3163, 'text': 'Makrai'},
#  {'start': 78, 'end': 100, 'text': 'Rhabdopliuhum forsteni'},
#  {'start': 177, 'end': 195, 'text': 'Pseudorhabdium Jan'},
#  {'start': 870, 'end': 904, 'text': 'Pscudoihahdium longiceps Boulenger'},
#  {'start': 749, 'end': 780, 'text': 'Pseudorhabdium longiceps (Cant)'},
#  {'start': 782, 'end': 808, 'text': 'Calamaria longiceps Cantor'},
#  {'start': 9, 'end': 23, 'text': 'DIPTEROCARPACE'},
#  {'start': 36, 'end': 52, 'text': 'S. Talura, Roxb.'},
#  {'start': 59, 'end': 78, 'text': 'S. laccifera, Heyne'},
#  {'start': 103, 'end': 126, 'text': 'Vatica laccifera, Wight'},
#  {'start': 145, 'end': 151, 'text': 'Talura'},
#  {'start': 153, 'end': 159, 'text': 'talari'},
#  {'start': 167, 'end': 173, 'text': 'Jalari'},
#  {'start': 181, 'end': 187, 'text': 'Jhalli'},
#  {'start': 965, 'end': 984, 'text': 'S. floribunda, Kurz'},
#  {'start': 1039, 'end': 1057, 'text': 'S. assamica, Dyer.'},
#  {'start': 1064, 'end': 1069, 'text': 'Makai'},
#  {'start': 1568, 'end': 1587, 'text': 'S. gratissima, Dyer'},
#  {'start': 1843, 'end': 1859, 'text': 'PARASHOREA, Kurz'},
#  {'start': 1933, 'end': 1950, 'text': 'P. stellata, Kurz'},
#  {'start': 1995, 'end': 2016, 'text': 'Shorea stellata, Dyer'},
#  {'start': 2047, 'end': 2055, 'text': 'Kaunghmu'},
#  {'start': 2837, 'end': 2862, 'text': 'Parashorea stellata, Kurz'},
#  {'start': 2872, 'end': 2893, 'text': 'BALANOCARPUS, Beddome'},
#  {'start': 176, 'end': 201, 'text': 'Acrotrema lyratum, Hk. f.'},
#  {'start': 226,
#   'end': 274,
#   'text': 'A. uniflorum, Hk., var. bullatum, Hk. f. and Th.'},
#  {'start': 468,
#   'end': 509,
#   'text': 'Schumacheria angustifolia, Hk. f. and Th.'},
#  {'start': 644, 'end': 668, 'text': 'Wormia triquetra, Rotth.'},
#  {'start': 1018, 'end': 1051, 'text': 'Limacia cuspidata, Hk. f. and Th.'},
#  {'start': 1255, 'end': 1287, 'text': 'Alsodeia virgata, Hk. f. and Th.'},
#  {'start': 1516, 'end': 1553, 'text': 'Erythrospermum phytolaccoides, Gardn.'},
#  {'start': 1727, 'end': 1749, 'text': 'Aueria Gardneri, Clos.'},
#  {'start': 2078, 'end': 2105, 'text': 'Trichadenia zeylanica, Thw.'},
#  {'start': 2462, 'end': 2491, 'text': 'Adinandra lasiopetala, Chois.'},
#  {'start': 2784, 'end': 2814, 'text': 'Dipterocarpus zeylanicus, Thw.'},
#  {'start': 3106, 'end': 3131, 'text': 'Doona congestiflora, Thw.'},
#  {'start': 282, 'end': 290, 'text': 'TANGUILE'},
#  {'start': 292, 'end': 312, 'text': 'Shorea Talura, Roxb.'},
#  {'start': 314, 'end': 348, 'text': 'Dipterocarpus polyspermus, Blanco.'},
#  {'start': 355, 'end': 369, 'text': 'Dipterocarpeae'},
#  {'start': 381, 'end': 389, 'text': 'Tanguile'},
#  {'start': 391, 'end': 398, 'text': 'Taugile'},
#  {'start': 400, 'end': 407, 'text': 'Tangili'},
#  {'start': 194, 'end': 219, 'text': 'Epimys Luzonicus (Thomas)'},
#  {'start': 38, 'end': 66, 'text': 'Epitnys luteiventris (Allen)'},
#  {'start': 74, 'end': 95, 'text': 'Mus hdeiventris Allen'},
#  {'start': 227, 'end': 247, 'text': 'Mus luzonicus Thomas'},
#  {'start': 349, 'end': 377, 'text': 'Epimys magnirostris (Mearns)'},
#  {'start': 385, 'end': 408, 'text': 'Mus magnirostris Mearns'},
#  {'start': 498, 'end': 525, 'text': 'Epimys mindanensis (Mearns)'},
#  {'start': 533, 'end': 555, 'text': 'Mus mindanensis Mearns'},
#  {'start': 667, 'end': 694, 'text': 'Epimys mindorensis (Thomas)'},
#  {'start': 702, 'end': 725, 'text': 'Mus mindorensis Thomas,'},
#  {'start': 846, 'end': 872, 'text': 'Epimys neglectus (Jentink)'},
#  {'start': 880, 'end': 901, 'text': 'Mus neglectus Jentink'},
#  {'start': 948, 'end': 969, 'text': 'Epimys neglectus Lyon'},
#  {'start': 1054, 'end': 1078, 'text': 'Epimys negrinus (Thomas)'},
#  {'start': 1086, 'end': 1115, 'text': 'Mus ephippium negrinus Thomas'},
#  {'start': 1174, 'end': 1199, 'text': 'Epimys negrinus Hollister'},
#  {'start': 1303, 'end': 1331, 'text': 'Epimys norvegicus (Erxleben)'},
#  {'start': 1339, 'end': 1362, 'text': 'Mus norvegicus Erxleben'},
#  {'start': 1567, 'end': 1594, 'text': 'Epimys pantarensis (Mearns)'},
#  {'start': 1408, 'end': 1433, 'text': 'Epimys norwegicus Satunin'},
#  {'start': 1602, 'end': 1624, 'text': 'Mus pantarensis Mearns'},
#  {'start': 41, 'end': 52, 'text': 'PLATYMAIA1S'},
#  {'start': 616, 'end': 626, 'text': 'worcesteri'},
#  {'start': 632, 'end': 638, 'text': 'ingeri'},
#  {'start': 766, 'end': 775, 'text': 'guentheri'},
#  {'start': 1728, 'end': 1737, 'text': 'guentheri'},
#  {'start': 2996, 'end': 3024, 'text': 'Platymantis guentheri-ingeri'},
#  {'start': 3878, 'end': 3887, 'text': 'guentheri'},
#  {'start': 3981, 'end': 3987, 'text': 'ingeri'},
#  {'start': 3754, 'end': 3760, 'text': 'ingeri'},
#  {'start': 401, 'end': 410, 'text': 'guentheri'},
#  {'start': 412, 'end': 423, 'text': 'negrosensis'},
#  {'start': 425, 'end': 435, 'text': 'luzonensis'},
#  {'start': 441, 'end': 448, 'text': 'banahao'},
#  {'start': 1267, 'end': 1303, 'text': 'Cornufer guentheri: Alcala and Brown'},
#  {'start': 74, 'end': 84, 'text': 'Vatica, L.'},
#  {'start': 1034, 'end': 1039, 'text': 'Malva'},
#  {'start': 1292, 'end': 1296, 'text': 'Sida'}]

# %% [markdown]
# #### Eval on BB task corpus

# %%
PATH_TO_BB_GT = '../corpora/BB_GSC_brat/bb_clean/test'
PATH_TO_BB_PRED = "./output/TAXONFINDER/BB_pred"

# %%
response = run_taxonfinder(PATH_TO_BB_GT, PATH_TO_BB_PRED)
parse_taxonfinder(response, PATH_TO_BB_PRED)

# %%
get_precision_recall_f1_single_corpus(PATH_TO_BB_PRED, PATH_TO_BB_GT, criterion=exact)
# Out:
# $79.56$ & $63.25$ & $70.47$
#        precision  recall  f1-score
# Taxon   0.795597  0.6325  0.704735

# %%
get_precision_recall_f1_single_corpus(PATH_TO_BB_PRED, PATH_TO_BB_GT, criterion=approximate)
# Out:
# $80.19$ & $63.75$ & $71.03$
#        precision  recall  f1-score
# Taxon   0.801887  0.6375  0.710306

# %%
FN, FP, TP = get_FN_FP_TP_single_corpus(PATH_TO_BB_PRED, PATH_TO_BB_GT, criterion=exact)
